# %% [markdown]
# # 搜索与排名
# 这一章主要介绍一个搜索引擎的构造过程，我们利用它来对一组文档建立索引(index),并提供一些进一步的改进建议。
#
# 主要内容：
# - 检索网页（crawl）
# - 建立索引
# - 对网页进行搜索
# - 对搜索的结果进行排名

# %% [markdown]
# ## 搜索引擎的组成
# 简历搜索引擎有四个步骤：
# - 首先，找到一种搜集文档的办法。可以是用爬虫（scrapy等）抓取网页，也可以在固定数量的文档范围（某公司内部的网络）中进行搜集。
# - 其次，我们要建立索引。通常建立一张很大的表，表包含了文档以及不同单词的位置信息。
# - 第三步，我们需要查询返回一个经过排序的文档列表。这其中涉及到了度量方法，比如page-rank，tfidf。
# - 第四步（可选），建立一个神经网络，对查询结果进行排名。通过了解人们在搜索结果以后都点击了哪些链接，神经网络会将搜索过程与搜索结果关联起来。利用这一信息改变搜索结果的排列顺序。

# %% [markdown]
# 新建一个crawler类，其作用是检索网页和创建数据库

# %%
from urllib.parse import urljoin
from bs4 import BeautifulSoup
import requests

class crawler:
    
    # 初始化crawler类并传入数据库名称
    def __init__(self,dbname):
        pass
    def __del__(self):
        pass
    def dbcommit(self):
        pass
    
    # 辅助函数，用于获取条目的id，并且如果条目不存在，就将其加入数据库中
    def getentryid(self,table,field,value,createnew=True):
        return None
    
    # 为每个网页建立索引
    def addtoindex(self,url,soup):
        print('Indexing %s'%url)
        
    # 从一个HTML的网页中提取文字（不带标签的）
    def gettextonly(self,soup):
        return None
    
    # 根据任何非空白符进行分词处理
    def separatewords(self,text):
        return None
    
    # 如果url已经建立过索引，则返回ture
    def isindexed(self,url):
        return False
    
    # 添加一个关联两个网页的链接
    def addlinkref(self,urlForm,urlTo,linkText):
        pass
    
    # 从一小组网页开始进行广度优先搜索，直至某一给定深度，期间为网页建立索引
    def crawl(self,pages,depth=2):
        pass
    
    # 创建数据库表
    def createindextables(self):
        pass

# %% [markdown]
# 在crawler类中新增加一个crawl函数，该函数循环遍历网页列表，并针对每个网页调用addtoindex函数。
#
# 随后，该函数利用Beautiful Soup取到网页中的所有链接，并将这些链接加入到一个名为newpages的集合中。
#
# 循环结束之前，我们将newpages赋给pages

# %%
class crawler:
    # 初始化crawler类并传入数据库名称
    def __init__(self,dbname):
        pass
    def __del__(self):
        pass
    def dbcommit(self):
        pass
    
    # 辅助函数，用于获取条目的id，并且如果条目不存在，就将其加入数据库中
    def getentryid(self,table,field,value,createnew=True):
        return None
    
    # 为每个网页建立索引
    def addtoindex(self,url,soup):
        print('Indexing %s'%url)
        
    # 从一个HTML的网页中提取文字（不带标签的）
    def gettextonly(self,soup):
        return None
    
    # 根据任何非空白符进行分词处理
    def separatewords(self,text):
        return None
    
    # 如果url已经建立过索引，则返回ture
    def isindexed(self,url):
        return False
    
    # 添加一个关联两个网页的链接
    def addlinkref(self,urlForm,urlTo,linkText):
        pass
    
    # 从一小组网页开始进行广度优先搜索，直至某一给定深度，期间为网页建立索引
    def crawl(self,pages,depth=2):
        pass
    
    # 创建数据库表
    def createindextables(self):
        pass

    def crawl(self,pages,depth=2):
        headers = {
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_4) '
                      'AppleWebKit / 537.36(KHTML, likeGecko) Chrome / 52.0.2743.116Safari / 537.36'
        }
        for i in range(depth):
            newpages=set()
            for page in pages:
                try:
                    c=requests.get(page,headers)
                except:
                    print("could not open %s"%page)
                    continue
                plain_text=c.text
                soup=BeautifulSoup(plain_text,'html.parser')
                self.addtoindex(page,soup)

                links=soup('a')
                # print(links)
                for link in links:
                    # print(link.href)
                    if ('href' in link.attrs):
                        url=urljoin(page,link['href'])
                        if url.find("'")!=-1:
                            continue
                        url=url.split('#')[0] # 去掉位置部分
                        if (url[0:4]=='http' or url[0:4]=='https') and not self.isindexed(url):
                            newpages.add(url)
                        linkText=self.gettextonly(link)
                        self.addlinkref(page,url,linkText)

                self.dbcommit()
            pages=newpages

# %% [markdown]
# 用豆瓣图书测试一下，的确是好用的

# %%
pagelist=['https://book.douban.com/'] #豆瓣读书
crawler=crawler('1')
crawler.crawl(pagelist)
# Out:
# Indexing https://book.douban.com/
# Indexing https://read.douban.com/ebook/5083852/?dcs=book-hot&dcm=douban&dct=read-subject
# Indexing https://book.douban.com
# Indexing https://book.douban.com/subject/27046739/?icn=index-latestbook-subject
# Indexing https://book.douban.com/link2/?pre=0&vendor=dangdang&srcpage=bestseller&price=1980&pos=1&url=http%3A%2F%2Funion.dangdang.com%2Ftransfer.php%3Ffrom%3DP-306226-0-s26647769%26backurl%3Dhttp%3A%2F%2Fproduct.dangdang.com%2Fproduct.aspx%3Fproduct_id%3D23761145&srcsubj=&type=bkbuy&subject=26647769
# Indexing https://www.douban.com
# Indexing https://book.douban.com/tag/?view=type&icn=index-sorttags-all
# Indexing https://read.douban.com/ebooks?dcs=book-intro&dcm=douban
# Indexing https://movie.douban.com
# Indexing https://moment.douban.com
# Indexing https://book.douban.com/tag/散文
# Indexing https://book.douban.com/review/8583202/
# Indexing https://book.douban.com/review/best/
# Indexing https://book.douban.com/tag/言情
# Indexing https://book.douban.com/subject/1082154/?icn=index-book250-subject
# Indexing https://book.douban.com/subject/26670709/
# Indexing https://book.douban.com/library_invitation
# Indexing https://book.douban.com/subject/27037148/?icn=index-latestbook-subject
# Indexing https://book.douban.com/tag/哲学
# Indexing https://book.douban.com/cart/
# Indexing https://www.douban.com/group
# Indexing https://www.douban.com/about?policy=disclaimer
# Indexing https://book.douban.com/subject/27064644/?icn=index-latestbook-subject
# Indexing https://book.douban.com/subject/27001225/?icn=index-editionrecommend
# Indexing https://read.douban.com/ebook/34384688/?dcs=book-hot&dcm=douban&dct=read-subject
# Indexing https://book.douban.com/subject/26340138/
# Indexing https://book.douban.com/subject/1084336/?icn=index-book250-subject
# Indexing https://book.douban.com/subject/27055849/?icn=index-latestbook-subject
# Indexing https://book.douban.com/subject/26976924/?icn=index-topchart-subject
# Indexing https://www.douban.com/people/cyh328/
# Indexing https://book.douban.com/tag/推理
# Indexing https://book.douban.com/subject/10554308/
# Indexing https://book.douban.com/subject/27034332/?icn=index-latestbook-subject
# Indexing https://book.douban.com/link2/?pre=0&vendor=dangdang&srcpage=bestseller&price=6900&pos=7&url=http%3A%2F%2Funion.dangdang.com%2Ftransfer.php%3Ffrom%3DP-306226-0-s26738072%26backurl%3Dhttp%3A%2F%2Fproduct.dangdang.com%2Fproduct.aspx%3Fproduct_id%3D23808035&srcsubj=&type=bkbuy&subject=26738072
# Indexing https://book.douban.com/subject/26939969/?icn=index-latestbook-subject
# Indexing https://book.douban.com/chart?icn=index-topchart-nonfiction
# Indexing https://read.douban.com/ebook/33431245/?dcs=book-hot&dcm=douban&dct=read-subject
# Indexing https://book.douban.com/subject/27017251/?icn=index-latestbook-subject
# Indexing https://www.douban.com/note/624530936/
# Indexing https://book.douban.com/subject/27055905/?icn=index-latestbook-subject
# Indexing https://book.douban.com/link2/?pre=0&vendor=jingdong&srcpage=bestseller&price=5080&pos=9&url=http%3A%2F%2Funion-click.jd.com%2Fjdc%3Fe%3D%26p%3DAyIOZR5aEQISA1AYUyUCEgFVGFkdASJDCkMFSjJLQhBaUAscSkIBR0ROVw1VC0dFFQIUB1YZUxYdS0IJRmsPAmlCHRtBFmFgfSF9DkAGc1ISbwVTDh43Uh5cEwUbBFIrWxEDFgNlK1sUMkBpja3tzaejG4Gx1MCKhTdUK1sQCxsDUBldEwMWBFQrXCXbkrCDucnMnJjS3YxrJTIi%26t%3DW1dCFBBFC1pXUwkEAEAdQFkJBVsVBBIEVxNYCltXWwg%253D&srcsubj=&type=bkbuy&subject=26670709
# Indexing https://book.douban.com/tag/家居
# Indexing https://book.douban.com/tag/神经网络
# Indexing https://book.douban.com/subject/27052400/?icn=index-editionrecommend
# Indexing https://market.douban.com/book/shanzhisiji?utm_campaign=book_freyr_section&utm_source=douban&utm_medium=pc_web
# Indexing https://read.douban.com/ebook/32433764/?dcs=book-hot&dcm=douban&dct=read-subject
# Indexing https://book.douban.com/latest?icn=index-latestbook-all
# Indexing https://www.douban.com/doubanapp/app?channel=top-nav
# Indexing https://www.douban.com/people/81527250/
# Indexing https://book.douban.com/tag/旅行
# Indexing https://book.douban.com/tag/算法
# Indexing https://book.douban.com/link2/?pre=0&vendor=dangdang&srcpage=bestseller&price=2730&pos=5&url=http%3A%2F%2Funion.dangdang.com%2Ftransfer.php%3Ffrom%3DP-306226-0-s10554308%26backurl%3Dhttp%3A%2F%2Fproduct.dangdang.com%2Fproduct.aspx%3Fproduct_id%3D22935553&srcsubj=&type=bkbuy&subject=10554308
# Indexing https://book.douban.com/subject/26853356/?icn=index-topchart-subject
# Indexing https://book.douban.com/review/8542286/?icn=index-topchart-subject
# Indexing https://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=Android
# Indexing https://book.douban.com/tag/励志
# Indexing https://book.douban.com/tag/漫画
# Indexing https://book.douban.com/subject/26972277/
# Indexing https://www.douban.com/accounts/login?source=book
# Indexing https://book.douban.com/review/8514711/?icn=index-topchart-subject
# Indexing https://book.douban.com/subject/27030507/?icn=index-latestbook-subject
# Indexing https://book.douban.com/tag/股票
# Indexing https://book.douban.com/tag/传记
# Indexing https://book.douban.com/review/8544907/?icn=index-topchart-subject
# Indexing https://read.douban.com/ebook/24787676/?dcs=book-hot&dcm=douban&dct=read-subject
# Indexing https://book.douban.com/link2/?pre=0&vendor=jingdong&srcpage=bestseller&price=2940&pos=4&url=http%3A%2F%2Funion-click.jd.com%2Fjdc%3Fe%3D%26p%3DAyIOZR5aEQISA1AYUyUCEgJRGFIQAyJDCkMFSjJLQhBaUAscSkIBR0ROVw1VC0dFFQIXA1YSXhQdS0IJRmt3X0RALUYbTmFGVzRTE0VQSUBLUF5TDh43Uh5cEwUbBFIrWxEDFgNlK1sUMkBpja3tzaejG4Gx1MCKhTdUK1sQCxsDUBpfEQAXD1YrXCXbkrCDucnMnJjS3YxrJTIi%26t%3DW1dCFBBFC1pXUwkEAEAdQFkJBVsVBxYEXB5aCltXWwg%253D&srcsubj=&type=bkbuy&subject=25862578
# Indexing https://market.douban.com/book/?utm_campaign=book_freyr_section&utm_source=douban&utm_medium=pc_web
# Indexing https://book.douban.com/tag/名著
# Indexing https://book.douban.com/tag/健康
# Indexing https://book.douban.com/subject/26963321/?icn=index-topchart-subject
# Indexing https://book.douban.com/review/8607438/
# Indexing https://book.douban.com/standbyme/2016?source=navigation
# Indexing https://book.douban.com/subject/27039964/?icn=index-latestbook-subject
# Indexing https://book.douban.com/tag/日本文学
# Indexing https://read.douban.com/ebook/35023547/?dcs=book-hot&dcm=douban&dct=read-subject
# Indexing https://www.douban.com/people/160270853/
# Indexing https://book.douban.com/link2/?pre=0&vendor=jingdong&srcpage=bestseller&price=2420&pos=10&url=http%3A%2F%2Funion-click.jd.com%2Fjdc%3Fe%3D%26p%3DAyIOZR5aEQISA1AYUyUCEgBTEloUBCJDCkMFSjJLQhBaUAscSkIBR0ROVw1VC0dFFQIVAVwaWhMdS0IJRmtGRHFcM3ApUWJpcT5QLVFgagE3aVlDDh43Uh5cEwUbBFIrWxEDFgNlK1sUMkBpja3tzaejG4Gx1MCKhTdUK1sQCxsDUBpcEwYRBlQrXCXbkrCDucnMnJjS3YxrJTIi%26t%3DW1dCFBBFC1pXUwkEAEAdQFkJBVsVBRQOVBpdCltXWwg%253D&srcsubj=&type=bkbuy&subject=26340138
# Indexing https://www.douban.com/doubanapp/
# Indexing https://book.douban.com/chart?subcat=F&icn=index-topchart-fiction
# Indexing https://book.douban.com/subject/27013663/?icn=index-topchart-subject
# Indexing https://book.douban.com/tag/小说
# Indexing https://book.douban.com/link2/?pre=0&vendor=jingdong&srcpage=bestseller&price=3000&pos=2&url=http%3A%2F%2Funion-click.jd.com%2Fjdc%3Fe%3D%26p%3DAyIOZR5aEQISA1AYUyUCEgZcG1wdBiJDCkMFSjJLQhBaUAscSkIBR0ROVw1VC0dFFQITDlUcUxEdS0IJRmtGBFtnNEw8UWBlcVdkCGsYV1A3ZDJlDh43Uh5cEwUbBFIrWxEDFgNlK1sUMkBpja3tzaejG4Gx1MCKhTdUK1sQCxsDUBpcHQoWBFcrXCXbkrCDucnMnJjS3YxrJTIi%26t%3DW1dCFBBFC1pXUwkEAEAdQFkJBVsVAxsHUhNfCltXWwg%253D&srcsubj=&type=bkbuy&subject=10564071
# Indexing https://market.douban.com/book/ruhuazaiye?utm_campaign=book_freyr_section&utm_source=douban&utm_medium=pc_web
# Indexing https://book.douban.com/tag/互联网
# Indexing https://book.douban.com/tag/职场
# Indexing https://book.douban.com/
# Indexing https://market.douban.com/book/busiyi?utm_campaign=book_freyr_section&utm_source=douban&utm_medium=pc_web
# Indexing https://book.douban.com/subject/26944962/?icn=index-topchart-subject
# Indexing https://book.douban.com/subject/27041650/?icn=index-editionrecommend
# Indexing https://book.douban.com/tag/电影
# Indexing https://book.douban.com/link2/?pre=0&vendor=dangdang&srcpage=bestseller&price=2340&pos=10&url=http%3A%2F%2Funion.dangdang.com%2Ftransfer.php%3Ffrom%3DP-306226-0-s26972277%26backurl%3Dhttp%3A%2F%2Fproduct.dangdang.com%2Fproduct.aspx%3Fproduct_id%3D24188188&srcsubj=&type=bkbuy&subject=26972277
# Indexing https://read.douban.com/ebook/34907446/?dcs=book-hot&dcm=douban&dct=read-subject
# Indexing https://book.douban.com/link2/?pre=0&vendor=jingdong&srcpage=bestseller&price=2510&pos=3&url=http%3A%2F%2Funion-click.jd.com%2Fjdc%3Fe%3D%26p%3DAyIOZR5aEQISA1AYUyUCEg9XHVwXCyJDCkMFSjJLQhBaUAscSkIBR0ROVw1VC0dFFQIaBVMcWRwdS0IJRmtcemRcT24FUmETYS9mEmBnFXAnWB9lDh43Uh5cEwUbBFIrWxEDFgNlK1sUMkBpja3tzaejG4Gx1MCKhTdUK1sQCxsDUBtdFgAbBlcrXCXbkrCDucnMnJjS3YxrJTIi%26t%3DW1dCFBBFC1pXUwkEAEAdQFkJBVsVChABUhlSCltXWwg%253D&srcsubj=&type=bkbuy&subject=26805837
# Indexing https://book.douban.com/tag/奇幻
# Indexing https://book.douban.com/link2/?pre=0&vendor=dangdang&srcpage=bestseller&price=5510&pos=8&url=http%3A%2F%2Funion.dangdang.com%2Ftransfer.php%3Ffrom%3DP-306226-0-s10517238%26backurl%3Dhttp%3A%2F%2Fproduct.dangdang.com%2Fproduct.aspx%3Fproduct_id%3D22616096&srcsubj=&type=bkbuy&subject=10517238
# Indexing https://book.douban.com/tag/武侠
# Indexing https://book.douban.com/subject/3191328/?icn=index-book250-subject
# Indexing http://weibo.com/doubandushu
# Indexing https://book.douban.com/subject/26356948/
# Indexing https://book.douban.com/subject/10517238/
# Indexing https://book.douban.com/tag/历史
# Indexing https://book.douban.com/tag/美食
# Indexing https://book.douban.com/tag/建筑
# Indexing https://book.douban.com/subject/27005756/?icn=index-latestbook-subject
# Indexing https://read.douban.com/ebooks/category/all/?sort=top&dcs=book-hot&dcm=douban&dct=read-more
# Indexing https://book.douban.com/subject/1873231/?icn=index-book250-subject
# Indexing https://read.douban.com/ebook/3021999/?dcs=book-hot&dcm=douban&dct=read-subject
# Indexing https://book.douban.com/subject/26805837/
# Indexing https://book.douban.com/tag/经济学
# Indexing https://book.douban.com/tag/港台
# Indexing https://read.douban.com/?dcs=top-nav&dcm=douban
# Indexing https://book.douban.com/tag/科普
# Indexing https://www.douban.com/doubanapp/app?channel=qipao
# Indexing https://book.douban.com/annual2016/?source=navigation
# Indexing https://book.douban.com/tag/随笔
# Indexing https://www.douban.com/location
# Indexing https://book.douban.com/review/latest/
# Indexing https://book.douban.com/subject/27042830/?icn=index-latestbook-subject
# Indexing https://book.douban.com/subject/11637889/
# Indexing https://book.douban.com/subject/27000152/?icn=index-topchart-subject
# Indexing https://book.douban.com/subject/1018153/?icn=index-book250-subject
# Indexing https://book.douban.com/subject/27001165/?icn=index-latestbook-subject
# Indexing https://book.douban.com/tag/理财
# Indexing https://book.douban.com/link2/?pre=0&vendor=dangdang&srcpage=bestseller&price=1989&pos=3&url=http%3A%2F%2Funion.dangdang.com%2Ftransfer.php%3Ffrom%3DP-306226-0-s26666472%26backurl%3Dhttp%3A%2F%2Fproduct.dangdang.com%2Fproduct.aspx%3Fproduct_id%3D23822200&srcsubj=&type=bkbuy&subject=26666472
# Indexing https://www.douban.com/people/1053540/
# Indexing https://market.douban.com/book/lynch?utm_campaign=book_freyr_section&utm_source=douban&utm_medium=pc_web
# Indexing https://book.douban.com/tag/回忆录
# Indexing https://book.douban.com/tag/交互设计
# Indexing https://book.douban.com/subject/1065970/?icn=index-book250-subject
# Indexing https://book.douban.com/subject/27045564/?icn=index-latestbook-subject
# Indexing https://market.douban.com/book/talese?utm_campaign=book_freyr_section&utm_source=douban&utm_medium=pc_web
# Indexing https://read.douban.com/ebook/35051471/?dcs=book-hot&dcm=douban&dct=read-subject
# Indexing https://book.douban.com/tag/青春
# Indexing https://book.douban.com/subject/27053755/?icn=index-latestbook-subject
# Indexing https://book.douban.com/subject/26610864/
# Indexing https://book.douban.com/subject/27045129/?icn=index-latestbook-subject
# Indexing https://book.douban.com/subject/27004926/?icn=index-latestbook-subject
# Indexing https://book.douban.com/subject/5431784/?icn=index-latestbook-subject
# Indexing https://book.douban.com/link2/?pre=0&vendor=jingdong&srcpage=bestseller&price=2810&pos=7&url=http%3A%2F%2Funion-click.jd.com%2Fjdc%3Fe%3D%26p%3DAyIOZR5aEQISA1AYUyUCEQZcGlgVBiJDCkMFSjJLQhBaUAscSkIBR0ROVw1VC0dFFQETDlQYWxEdS0IJRmtcRlZeLm9cdWBmAF1TGHYAaUIdXhN1Dh5pVhpbEx4TAEkaXQQBEAxVHlAVCiIAUBxdEgsRAGUbXxQGFjdlG1olUHzf462DsLMO0%252F%252BUjp2VIgZlG14dBRsCXB5fHQobA2Uca8yCpdH3iYKLiMePwitrJTI%253D%26t%3DW1dCFBBFC1pXUwkEAEAdQFkJBVsWAxsGVhtfCltXWwg%253D&srcsubj=&type=bkbuy&subject=27028847
# Indexing https://book.douban.com/tag/编程
# Indexing https://book.douban.com/tag/绘本
# Indexing https://book.douban.com/tag/诗歌
# Indexing https://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=iOS
# Indexing https://book.douban.com/tag/教育
# Indexing https://music.douban.com
# Indexing https://book.douban.com/subject/27012054/?icn=index-topchart-subject
# Indexing https://book.douban.com/tag/管理
# Indexing https://site.douban.com/book/
# Indexing https://read.douban.com/ebooks/?dcs=book-nav&dcm=douban
# Indexing https://book.douban.com/tag/灵修
# Indexing https://market.douban.com/?utm_campaign=douban_top_nav&utm_source=douban&utm_medium=pc_web
# Indexing https://book.douban.com/link2/?pre=0&vendor=jingdong&srcpage=bestseller&price=2260&pos=1&url=http%3A%2F%2Funion-click.jd.com%2Fjdc%3Fe%3D%26p%3DAyIOZR5aEQISA1AYUyUCEgFRHVgUByJDCkMFSjJLQhBaUAscSkIBR0ROVw1VC0dFFQIUA1MYWhAdS0IJRmsSVEljCGxZE2BmBAtcAWV1G1ssZVtDDh43Uh5cEwUbBFIrWxEDFgNlK1sUMkBpja3tzaejG4Gx1MCKhTdUK1sQCxsDUBpeEgMUBl0rXCXbkrCDucnMnJjS3YxrJTIi%26t%3DW1dCFBBFC1pXUwkEAEAdQFkJBVsVBBYBVhpeCltXWwg%253D&srcsubj=&type=bkbuy&subject=26610864
# Indexing https://book.douban.com/link2/?pre=0&vendor=dangdang&srcpage=bestseller&price=2770&pos=9&url=http%3A%2F%2Funion.dangdang.com%2Ftransfer.php%3Ffrom%3DP-306226-0-s26978921%26backurl%3Dhttp%3A%2F%2Fproduct.dangdang.com%2Fproduct.aspx%3Fproduct_id%3D23932960&srcsubj=&type=bkbuy&subject=26978921
# Indexing https://book.douban.com/subject/1080370/?icn=index-book250-subject
# Indexing https://book.douban.com/review/8556897/?icn=index-topchart-subject
# Indexing https://book.douban.com/subject/27055728/?icn=index-editionrecommend
# Indexing https://book.douban.com/subject/27012339/?icn=index-latestbook-subject
# Indexing https://book.douban.com/tag/童话
# Indexing https://book.douban.com/subject/5275059/?icn=index-book250-subject
# Indexing https://book.douban.com/subject/27039453/?icn=index-latestbook-subject
# Indexing https://book.douban.com/subject/27025114/?icn=index-latestbook-subject
# Indexing https://book.douban.com/review/8512322/?icn=index-topchart-subject
# Indexing https://ypy.douban.com
# Indexing https://book.douban.com/review/8608016/
# Indexing https://book.douban.com/subject/27028847/
# Indexing https://book.douban.com/link2/?pre=0&vendor=jingdong&srcpage=bestseller&price=2800&pos=8&url=http%3A%2F%2Funion-click.jd.com%2Fjdc%3Fe%3D%26p%3DAyIOZR5aEQISA1AYUyUCEg9QG10WCyJDCkMFSjJLQhBaUAscSkIBR0ROVw1VC0dFFQIaAlUdWBwdS0IJRmtsSkRVME0ZRWF0YQoTXmV4EBkWbVhTDh43Uh5cEwUbBFIrWxEDFgNlK1sUMkBpja3tzaejG4Gx1MCKhTdUK1sQCxsDUBpcEQQWDlMrXCXbkrCDucnMnJjS3YxrJTIi%26t%3DW1dCFBBFC1pXUwkEAEAdQFkJBVsVChcHUxhSCltXWwg%253D&srcsubj=&type=bkbuy&subject=26802388
# Indexing https://book.douban.com/tag/设计
# Indexing https://book.douban.com/subject/26870453/?icn=index-latestbook-subject
# Indexing https://book.douban.com/subject/26897699/
# Indexing https://book.douban.com/subject/26974839/?icn=index-latestbook-subject
# Indexing https://book.douban.com/tag/商业
# Indexing https://book.douban.com/subject/1770782/?icn=index-book250-subject
# Indexing https://book.douban.com/subject/25862578/
# Indexing https://market.douban.com/book/baiguiyexing?utm_campaign=book_freyr_section&utm_source=douban&utm_medium=pc_web
# Indexing https://book.douban.com/review/8618835/
# Indexing https://www.douban.com/partner/
# Indexing https://book.douban.com/subject/26893260/?icn=index-topchart-subject
# Indexing https://book.douban.com/subject/26802388/
# Indexing https://book.douban.com/subject/26962683/?icn=index-latestbook-subject
# Indexing https://book.douban.com/review/8603586/
# Indexing https://book.douban.com/review/8608469/
# Indexing https://book.douban.com/review/8608093/
# Indexing https://book.douban.com/tag/企业史
# Indexing https://book.douban.com/subject/10564071/
# Indexing https://book.douban.com/tag/音乐
# Indexing https://market.douban.com/cart/?utm_campaign=book_nav_cart&utm_source=douban&utm_medium=pc_web
# Indexing https://book.douban.com/subject/27029890/?icn=index-topchart-subject
# Indexing https://book.douban.com/subject/27042365/?icn=index-latestbook-subject
# Indexing https://read.douban.com/ebook/34157247/?dcs=book-hot&dcm=douban&dct=read-subject
# Indexing https://book.douban.com/link2/?pre=0&vendor=dangdang&srcpage=bestseller&price=3140&pos=6&url=http%3A%2F%2Funion.dangdang.com%2Ftransfer.php%3Ffrom%3DP-306226-0-s11637889%26backurl%3Dhttp%3A%2F%2Fproduct.dangdang.com%2Fproduct.aspx%3Fproduct_id%3D22864933&srcsubj=&type=bkbuy&subject=11637889
# Indexing https://www.douban.com/hnypt/variformcyst.py
# Indexing https://book.douban.com/subject/26936410/?icn=index-editionrecommend
# Indexing https://douban.fm/?from_=shire_top_nav
# Indexing https://book.douban.com/subject/26738072/
# Indexing https://www.douban.com/accounts/register?source=book
# Indexing https://www.douban.com/jobs
# Indexing https://book.douban.com/link2/?pre=0&vendor=jingdong&srcpage=bestseller&price=2340&pos=5&url=http%3A%2F%2Funion-click.jd.com%2Fjdc%3Fe%3D%26p%3DAyIOZR5aEQISA1AYUyUCEgBcHVIRCyJDCkMFSjJLQhBaUAscSkIBR0ROVw1VC0dFFQIVDlMSXxwdS0IJRmt1YGJUDkcmC2dQHQcTMF5hb34AeVxTDh43Uh5cEwUbBFIrWxEDFgNlK1sUMkBpja3tzaejG4Gx1MCKhTdUK1sQCxsDUBpeHQcVAVcrXCXbkrCDucnMnJjS3YxrJTIi%26t%3DW1dCFBBFC1pXUwkEAEAdQFkJBVsVBRsBXB9SCltXWwg%253D&srcsubj=&type=bkbuy&subject=26356948
# Indexing https://book.douban.com/review/8450484/?icn=index-topchart-subject
# Indexing https://book.douban.com/subject/27043711/?icn=index-latestbook-subject
# Indexing https://www.douban.com/about?topic=contactus
# Indexing https://book.douban.com/review/8503927/?icn=index-topchart-subject
# Indexing https://book.douban.com/subject/26666472/
# Indexing https://help.douban.com/?app=book
# Indexing https://book.douban.com/tag/科幻
# Indexing https://book.douban.com/tag/金融
# Indexing https://book.douban.com/subject/26712441/?icn=index-latestbook-subject
# Indexing https://book.douban.com/link2/?pre=0&vendor=jingdong&srcpage=bestseller&price=2360&pos=6&url=http%3A%2F%2Funion-click.jd.com%2Fjdc%3Fe%3D%26p%3DAyIOZR5aEQISA1AYUyUCEg9dHVwVBiJDCkMFSjJLQhBaUAscSkIBR0ROVw1VC0dFFQIaD1McWxEdS0IJRmtKAUsAVVIeZ2AadSNCHAtjUHwyYyRDDh43Uh5cEwUbBFIrWxEDFgNlK1sUMkBpja3tzaejG4Gx1MCKhTdUK1sQCxsDUBhaEwYWBVIrXCXbkrCDucnMnJjS3YxrJTIi%26t%3DW1dCFBBFC1pXUwkEAEAdQFkJBVsVChoBUhtfCltXWwg%253D&srcsubj=&type=bkbuy&subject=26897699
# Indexing https://book.douban.com/subject/27020528/?icn=index-latestbook-subject
# Indexing https://book.douban.com/review/8555888/?icn=index-topchart-subject
# Indexing https://book.douban.com/subject/27056409/?icn=index-latestbook-subject
# Indexing https://www.douban.com/about
# Indexing https://dongxi.douban.com/?dcs=top-nav&dcm=douban
# Indexing https://book.douban.com/tag/?view=type&icn=index-sorttags-hot
# Indexing https://book.douban.com/subject/26975609/?icn=index-topchart-subject
# Indexing https://book.douban.com/link2/?pre=0&vendor=dangdang&srcpage=bestseller&price=2730&pos=2&url=http%3A%2F%2Funion.dangdang.com%2Ftransfer.php%3Ffrom%3DP-306226-0-s25862578%26backurl%3Dhttp%3A%2F%2Fproduct.dangdang.com%2Fproduct.aspx%3Fproduct_id%3D23464478&srcsubj=&type=bkbuy&subject=25862578
# Indexing https://book.douban.com/subject/26978921/
# Indexing https://book.douban.com/subject/1770782/
# Indexing https://book.douban.com/subject/27017794/?icn=index-latestbook-subject
# Indexing https://book.douban.com/subject/27021974/?icn=index-latestbook-subject
# Indexing https://book.douban.com/link2/?pre=0&vendor=dangdang&srcpage=bestseller&price=1450&pos=4&url=http%3A%2F%2Funion.dangdang.com%2Ftransfer.php%3Ffrom%3DP-306226-0-s1770782%26backurl%3Dhttp%3A%2F%2Fproduct.dangdang.com%2Fproduct.aspx%3Fproduct_id%3D23274638&srcsubj=&type=bkbuy&subject=1770782
# Indexing https://book.douban.com/subject/26487578/?icn=index-latestbook-subject
# Indexing https://book.douban.com/subject/26940525/?icn=index-latestbook-subject
# Indexing https://book.douban.com/tag/通信
# Indexing https://book.douban.com/tag/营销
# Indexing https://book.douban.com/review/8424009/?icn=index-topchart-subject
# Indexing https://book.douban.com/subject/26647769/
# Indexing https://book.douban.com/subject/27037182/?icn=index-latestbook-subject
# Indexing https://book.douban.com/subject/27046066/?icn=index-latestbook-subject
# Indexing https://book.douban.com/top250?icn=index-book250-all
# Indexing https://book.douban.com/review/8545597/?icn=index-topchart-subject
# Indexing https://market.douban.com/book?utm_campaign=book_nav_freyr&utm_source=douban&utm_medium=pc_web

# %% [markdown]
# ## 建立索引
# 我们需要为全文索引建立数据库。索引对应于一个列表，其中包含了所有不同的单词、这些单词所在的文档，以及单词在文档中出现的位置。

# %% [markdown]
# ### 建立数据库Schema
# 在crawler类的末尾添加createindextables()函数

# %%
import sqlite3

# %%
class crawler:
    # 初始化crawler类并传入数据库名称
    def __init__(self,dbname):
        self.con=sqlite3.connect(dbname)
        
    def __del__(self):
        self.con.close()
        
    def dbcommit(self):
        self.con.commit()
    
    # 辅助函数，用于获取条目的id，并且如果条目不存在，就将其加入数据库中
    def getentryid(self,table,field,value,createnew=True):
        return None
    
    # 为每个网页建立索引
    def addtoindex(self,url,soup):
        print('Indexing %s'%url)
        
    # 从一个HTML的网页中提取文字（不带标签的）
    def gettextonly(self,soup):
        return None
    
    # 根据任何非空白符进行分词处理
    def separatewords(self,text):
        return None
    
    # 如果url已经建立过索引，则返回ture
    def isindexed(self,url):
        return False
    
    # 添加一个关联两个网页的链接
    def addlinkref(self,urlForm,urlTo,linkText):
        pass
    
    # 从一小组网页开始进行广度优先搜索，直至某一给定深度，期间为网页建立索引
    def crawl(self,pages,depth=2):
        pass
    
    # 创建数据库表
    def createindextables(self):
        pass

    def crawl(self,pages,depth=2):
        headers = {
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_4) '
                      'AppleWebKit / 537.36(KHTML, likeGecko) Chrome / 52.0.2743.116Safari / 537.36'
        }
        for i in range(depth):
            newpages=set()
            for page in pages:
                try:
                    c=requests.get(page,headers)
                except:
                    print("could not open %s"%page)
                    continue
                plain_text=c.text
                soup=BeautifulSoup(plain_text,'html.parser')
                self.addtoindex(page,soup)

                links=soup('a')
                # print(links)
                for link in links:
                    # print(link.href)
                    if ('href' in link.attrs):
                        url=urljoin(page,link['href'])
                        if url.find("'")!=-1:
                            continue
                        url=url.split('#')[0] # 去掉位置部分
                        if (url[0:4]=='http' or url[0:4]=='https') and not self.isindexed(url):
                            newpages.add(url)
                        linkText=self.gettextonly(link)
                        self.addlinkref(page,url,linkText)

                self.dbcommit()
            pages=newpages
    
    def createindextables(self):
        self.con.execute('create table urllist(url)')  # urlist保存已经过索引的URL列表
        self.con.execute('create table wordlist(word)') # wordlist保存单词列表
        self.con.execute('create table wordlocation(urlid,wordid,location)') # wordlocation保存单词在文档中所处的位置的列表
        self.con.execute('create table link(fromid integer,toid integer)') # 保存两个URL ID，指明一张表到另外一张表的链接关系
        self.con.execute('create table linkwords(wordid,linkid)') # 记录了哪些单词与链接实际相关
        self.con.execute('create index wordidx on wordlist(word)')
        self.con.execute('create index urlidx on urllist(url)')
        self.con.execute('create index wordurlidx on wordlocation(wordid)')
        self.con.execute('create index urltoidx on link(toid)')
        self.con.execute('create index urlfromidx on link(fromid)')
        self.dbcommit()

# %%
crawler=crawler('searchindex.db')
crawler.createindextables()

# %% [markdown]
# ### 在网页中查找单词
# 网上下载的文件都是HTML格式的，其中包含大量的标签、属性，以及其它不在索引范围内的信息。
#
# 我们首先要从网页中提取出所有的文字部分。
#
# 完善gettextonly函数

# %%
class crawler:
    # 初始化crawler类并传入数据库名称
    def __init__(self,dbname):
        self.con=sqlite3.connect(dbname)
        
    def __del__(self):
        self.con.close()
        
    def dbcommit(self):
        self.con.commit()
    
    # 辅助函数，用于获取条目的id，并且如果条目不存在，就将其加入数据库中
    def getentryid(self,table,field,value,createnew=True):
        return None
    
    # 为每个网页建立索引
    def addtoindex(self,url,soup):
        print('Indexing %s'%url)
        
    # 从一个HTML的网页中提取文字（不带标签的）
    def gettextonly(self,soup):
        v=soup.string
        if v==None:
            c=soup.contents
            resulttext=''
            for t in c:
                subtext=self.gettextonly(t)
                resulttext+=subtext+'\n'
            return resulttext
        else:
            return v.strip()
    
    # 根据任何非空白符进行分词处理
    def separatewords(self,text):
        return None
    
    # 如果url已经建立过索引，则返回ture
    def isindexed(self,url):
        return False
    
    # 添加一个关联两个网页的链接
    def addlinkref(self,urlForm,urlTo,linkText):
        pass
    
    # 从一小组网页开始进行广度优先搜索，直至某一给定深度，期间为网页建立索引
    def crawl(self,pages,depth=2):
        headers = {
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_4) '
                      'AppleWebKit / 537.36(KHTML, likeGecko) Chrome / 52.0.2743.116Safari / 537.36'
        }
        for i in range(depth):
            newpages=set()
            for page in pages:
                try:
                    c=requests.get(page,headers)
                except:
                    print("could not open %s"%page)
                    continue
                plain_text=c.text
                soup=BeautifulSoup(plain_text,'html.parser')
                self.addtoindex(page,soup)

                links=soup('a')
                # print(links)
                for link in links:
                    # print(link.href)
                    if ('href' in link.attrs):
                        url=urljoin(page,link['href'])
                        if url.find("'")!=-1:
                            continue
                        url=url.split('#')[0] # 去掉位置部分
                        if (url[0:4]=='http' or url[0:4]=='https') and not self.isindexed(url):
                            newpages.add(url)
                        linkText=self.gettextonly(link)
                        self.addlinkref(page,url,linkText)

                self.dbcommit()
            pages=newpages
    
    # 创建数据库
    def createindextables(self):
        self.con.execute('create table urllist(url)')  # urlist保存已经过索引的URL列表
        self.con.execute('create table wordlist(word)') # wordlist保存单词列表
        self.con.execute('create table wordlocation(urlid,wordid,location)') # wordlocation保存单词在文档中所处的位置的列表
        self.con.execute('create table link(fromid integer,toid integer)') # 保存两个URL ID，指明一张表到另外一张表的链接关系
        self.con.execute('create table linkwords(wordid,linkid)') # 记录了哪些单词与链接实际相关
        self.con.execute('create index wordidx on wordlist(word)')
        self.con.execute('create index urlidx on urllist(url)')
        self.con.execute('create index wordurlidx on wordlocation(wordid)')
        self.con.execute('create index urltoidx on link(toid)')
        self.con.execute('create index urlfromidx on link(fromid)')
        self.dbcommit()

# %% [markdown]
# 接下来是separatewords函数，该函数将字符串拆分成一组独立的单词，以便我们将其加入索引中
#
# 思想是将非字母或者非数字的字符作为分割符
#
# 中文中这样肯定是行不通的，这里我使用了[jieba](https://github.com/fxsjy/jieba)对中文文本进行分词

# %%
import jieba
import re

class crawler:
    # 初始化crawler类并传入数据库名称
    def __init__(self,dbname):
        self.con=sqlite3.connect(dbname)
        
    def __del__(self):
        self.con.close()
        
    def dbcommit(self):
        self.con.commit()
    
    # 辅助函数，用于获取条目的id，并且如果条目不存在，就将其加入数据库中
    def getentryid(self,table,field,value,createnew=True):
        return None
    
    # 为每个网页建立索引
    def addtoindex(self,url,soup):
        print('Indexing %s'%url)
        
    # 从一个HTML的网页中提取文字（不带标签的）
    def gettextonly(self,soup):
        v=soup.string
        if v==None:
            c=soup.contents
            resulttext=''
            for t in c:
                subtext=self.gettextonly(t)
                resulttext+=subtext+'\n'
            return resulttext
        else:
            return v.strip()
    
    # 根据任何非空白符进行分词处理
    def separatewords(self,text):
        splitter=re.compile('\\W*')
        return [s.lower() for s in splitter.split(text) if s!='']
    
    # 中文的分词,使用jieba
    def separatewords_cn():
        seg_list = jieba.cut_for_search(text)  # 搜索引擎模式
        return [word for word in seg_list if len(word)>1]
    
    # 如果url已经建立过索引，则返回ture
    def isindexed(self,url):
        return False
    
    # 添加一个关联两个网页的链接
    def addlinkref(self,urlForm,urlTo,linkText):
        pass
    
    # 从一小组网页开始进行广度优先搜索，直至某一给定深度，期间为网页建立索引
    def crawl(self,pages,depth=2):
        headers = {
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_4) '
                      'AppleWebKit / 537.36(KHTML, likeGecko) Chrome / 52.0.2743.116Safari / 537.36'
        }
        for i in range(depth):
            newpages=set()
            for page in pages:
                try:
                    c=requests.get(page,headers)
                except:
                    print("could not open %s"%page)
                    continue
                plain_text=c.text
                soup=BeautifulSoup(plain_text,'html.parser')
                self.addtoindex(page,soup)

                links=soup('a')
                # print(links)
                for link in links:
                    # print(link.href)
                    if ('href' in link.attrs):
                        url=urljoin(page,link['href'])
                        if url.find("'")!=-1:
                            continue
                        url=url.split('#')[0] # 去掉位置部分
                        if (url[0:4]=='http' or url[0:4]=='https') and not self.isindexed(url):
                            newpages.add(url)
                        linkText=self.gettextonly(link)
                        self.addlinkref(page,url,linkText)
                self.dbcommit()
            pages=newpages
    
    # 创建数据库
    def createindextables(self):
        self.con.execute('create table urllist(url)')  # urlist保存已经过索引的URL列表
        self.con.execute('create table wordlist(word)') # wordlist保存单词列表
        self.con.execute('create table wordlocation(urlid,wordid,location)') # wordlocation保存单词在文档中所处的位置的列表
        self.con.execute('create table link(fromid integer,toid integer)') # 保存两个URL ID，指明一张表到另外一张表的链接关系
        self.con.execute('create table linkwords(wordid,linkid)') # 记录了哪些单词与链接实际相关
        self.con.execute('create index wordidx on wordlist(word)')
        self.con.execute('create index urlidx on urllist(url)')
        self.con.execute('create index wordurlidx on wordlocation(wordid)')
        self.con.execute('create index urltoidx on link(toid)')
        self.con.execute('create index urlfromidx on link(fromid)')
        self.dbcommit()

# %% [markdown]
# ### 加入索引
# 这里我们更新前面未实现的三个方法
# - addtoindex 该方法通过调用函数得到一个出现于网页中的单词的列表，然后，它会将网页以及所有单词加入索引，在网页和单词之间建立联系，并保存单词在文档中的位置
# - getentryid 该函数的作用是返回某一条目的ID。如果条目不存在，则程序会在数据库中新建一条记录，并将ID返回
# - isindexed 该函数判断网页是否已经存入数据库，如果存在，则判断是否有任何单词与之关联

# %%
from urllib.parse import urljoin
from bs4 import BeautifulSoup
import jieba
import re
import sqlite3
import requests

class crawler:
    # 初始化crawler类并传入数据库名称
    def __init__(self,dbname):
        self.con=sqlite3.connect(dbname)
        
    def __del__(self):
        self.con.close()
        
    def dbcommit(self):
        self.con.commit()
    
    # 辅助函数，用于获取条目的id，并且如果条目不存在，就将其加入数据库中
    def getentryid(self,table,field,value,createnew=True):
        cur=self.con.execute("select rowid from %s where %s='%s'"%(table,field,value))
        res=cur.fetchone()
        if res==None:
            cur=self.con.execute("insert into %s (%s) values ('%s')"%(table,field,value))
            return cur.lastrowid
        else:
            return res[0]
    
    # 为每个网页建立索引，英文
    def addtoindex(self,url,soup):
        if self.isindexed(url):
            return
        print('Indexing'+url)
        
        # 获取每个单词
        text=self.gettextonly(soup)
        words=self.separatewords(text)
        
        # 得到URL的id
        urlid=self.getentryid('urllist','url',url)
        
        # 将每个单词与该url关联
        for i in range(len(words)):
            word=words[1]
            if word in ignorewords:
                continue
            wordid=self.getentryid('wordlist','word',word)
            self.con.execute("Insert into wordlocation(urlid,wordid,location) values(%d,%d,%d)"%(urlid,wordid,i))
    
    # 为每个网页建立索引，中文
    def addtoindex_cn(self,url,soup):
        if self.isindexed(url):
            return
        print('Indexing'+url)
        
        # 获取每个单词
        text=self.gettextonly(soup)
        words=self.separatewords_cn(text)
        
        # 得到URL的id
        urlid=self.getentryid('urllist','url',url)
        
        # 将每个单词与该url关联
        for i in range(len(words)):
            word=words[1]
            wordid=self.getentryid('wordlist','word',word)
            self.con.execute("Insert into wordlocation(urlid,wordid,location) values(%d,%d,%d)"%(urlid,wordid,i))
        
    # 从一个HTML的网页中提取文字（不带标签的）
    def gettextonly(self,soup):
        v=soup.string
        if v==None:
            c=soup.contents
            resulttext=''
            for t in c:
                subtext=self.gettextonly(t)
                resulttext+=subtext+'\n'
            return resulttext
        else:
            return v.strip()
    
    # 根据任何非空白符进行分词处理
    def separatewords(self,text):
        splitter=re.compile('\\W*')
        return [s.lower() for s in splitter.split(text) if s!='']
    
    # 中文的分词,使用jieba
    def separatewords_cn(self,text):
        seg_list = jieba.cut_for_search(text)  # 搜索引擎模式
        return [word for word in seg_list if len(word)>1]
    
    # 如果url已经建立过索引，则返回ture
    def isindexed(self,url):
        u=self.con.execute("select rowid from urllist where url='%s'"%url).fetchone()
        if u!=None:
            # 检查它是否已经被检索过了
            v=self.con.execute('select * from wordlocation where urlid=%d' %u[0]).fetchone()
            if v!=None:
                return True
        return False
    
    # 添加一个关联两个网页的链接
    def addlinkref(self,urlForm,urlTo,linkText):
        pass
    
    # 从一小组网页开始进行广度优先搜索，直至某一给定深度，期间为网页建立索引
    def crawl(self,pages,depth=2):
        headers = {
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_4) '
                      'AppleWebKit / 537.36(KHTML, likeGecko) Chrome / 52.0.2743.116Safari / 537.36'
        }
        for i in range(depth):
            newpages=set()
            for page in pages:
                try:
                    c=requests.get(page,headers)
                except:
                    print("could not open %s"%page)
                    continue
                plain_text=c.text
                soup=BeautifulSoup(plain_text,'html.parser')
                # self.addtoindex(page,soup) # 英文添加索引
                self.addtoindex_cn(page,soup) # 中文添加索引

                links=soup('a')
                # print(links)
                for link in links:
                    # print(link.href)
                    if ('href' in link.attrs):
                        url=urljoin(page,link['href'])
                        if url.find("'")!=-1:
                            continue
                        url=url.split('#')[0] # 去掉位置部分
                        if (url[0:4]=='http' or url[0:4]=='https') and not self.isindexed(url):
                            newpages.add(url)
                        linkText=self.gettextonly(link)
                        self.addlinkref(page,url,linkText)

                self.dbcommit()
            pages=newpages
    
    # 创建数据库
    def createindextables(self):
        self.con.execute('create table urllist(url)')  # urlist保存已经过索引的URL列表
        self.con.execute('create table wordlist(word)') # wordlist保存单词列表
        self.con.execute('create table wordlocation(urlid,wordid,location)') # wordlocation保存单词在文档中所处的位置的列表
        self.con.execute('create table link(fromid integer,toid integer)') # 保存两个URL ID，指明一张表到另外一张表的链接关系
        self.con.execute('create table linkwords(wordid,linkid)') # 记录了哪些单词与链接实际相关
        self.con.execute('create index wordidx on wordlist(word)')
        self.con.execute('create index urlidx on urllist(url)')
        self.con.execute('create index wordurlidx on wordlocation(wordid)')
        self.con.execute('create index urltoidx on link(toid)')
        self.con.execute('create index urlfromidx on link(fromid)')
        self.dbcommit()

# %%
crawler=crawler('doubanbook.db')
crawler.createindextables()

# %%
pages=['https://book.douban.com/']
crawler.crawl(pages=pages)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\ETHANW~1\AppData\Local\Temp\jieba.cache
# Indexinghttps://book.douban.com/
# Loading model cost 0.796 seconds.
# Prefix dict has been built succesfully.
# Indexinghttps://book.douban.com/subject/26944962/?icn=index-topchart-subject
# Indexinghttps://www.douban.com/accounts/register?source=book
# Indexinghttps://book.douban.com/tag/历史
# Indexinghttps://book.douban.com/subject/26936410/?icn=index-editionrecommend
# Indexinghttps://book.douban.com/subject/27052400/?icn=index-editionrecommend
# Indexinghttps://book.douban.com/subject/1027191/?icn=index-book250-subject
# Indexinghttps://book.douban.com/tag/美食
# Indexinghttps://book.douban.com/subject/1022060/?icn=index-book250-subject
# Indexinghttps://book.douban.com/subject/27004926/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/standbyme/2016?source=navigation
# Indexinghttps://book.douban.com
# Indexinghttps://book.douban.com/tag/漫画
# Indexinghttps://book.douban.com/link2/?pre=0&vendor=dangdang&srcpage=bestseller&price=2770&pos=9&url=http%3A%2F%2Funion.dangdang.com%2Ftransfer.php%3Ffrom%3DP-306226-0-s26978921%26backurl%3Dhttp%3A%2F%2Fproduct.dangdang.com%2Fproduct.aspx%3Fproduct_id%3D23932960&srcsubj=&type=bkbuy&subject=26978921
# Indexinghttps://market.douban.com/?utm_campaign=douban_top_nav&utm_source=douban&utm_medium=pc_web
# Indexinghttps://market.douban.com/book/lynch?utm_campaign=book_freyr_section&utm_source=douban&utm_medium=pc_web
# Indexinghttps://book.douban.com/subject/26340138/
# Indexinghttps://book.douban.com/subject/26666472/
# Indexinghttps://book.douban.com/review/8618603/
# Indexinghttps://book.douban.com/subject/26976924/?icn=index-topchart-subject
# Indexinghttps://book.douban.com/link2/?pre=0&vendor=dangdang&srcpage=bestseller&price=2730&pos=2&url=http%3A%2F%2Funion.dangdang.com%2Ftransfer.php%3Ffrom%3DP-306226-0-s25862578%26backurl%3Dhttp%3A%2F%2Fproduct.dangdang.com%2Fproduct.aspx%3Fproduct_id%3D23464478&srcsubj=&type=bkbuy&subject=25862578
# Indexinghttps://book.douban.com/chart?icn=index-topchart-nonfiction
# Indexinghttps://www.douban.com/jobs
# Indexinghttps://book.douban.com/link2/?pre=0&vendor=dangdang&srcpage=bestseller&price=1980&pos=1&url=http%3A%2F%2Funion.dangdang.com%2Ftransfer.php%3Ffrom%3DP-306226-0-s26647769%26backurl%3Dhttp%3A%2F%2Fproduct.dangdang.com%2Fproduct.aspx%3Fproduct_id%3D23761145&srcsubj=&type=bkbuy&subject=26647769
# Indexinghttps://www.douban.com/note/624530936/
# Indexinghttps://market.douban.com/cart/?utm_campaign=book_nav_cart&utm_source=douban&utm_medium=pc_web
# Indexinghttps://book.douban.com/subject/27001225/?icn=index-editionrecommend
# Indexinghttps://read.douban.com/ebook/34157247/?dcs=book-hot&dcm=douban&dct=read-subject
# Indexinghttps://book.douban.com/tag/散文
# Indexinghttps://book.douban.com/review/latest/
# Indexinghttps://book.douban.com/tag/健康
# Indexinghttps://book.douban.com/link2/?pre=0&vendor=jingdong&srcpage=bestseller&price=2340&pos=5&url=http%3A%2F%2Funion-click.jd.com%2Fjdc%3Fe%3D%26p%3DAyIOZR5aEQISA1AYUyUCEgBcHVIRCyJDCkMFSjJLQhBaUAscSkIBR0ROVw1VC0dFFQIVDlMSXxwdS0IJRmt1YGJUDkcmC2dQHQcTMF5hb34AeVxTDh43Uh5cEwUbBFIrWxEDFgNlK1sUMkBpja3tzaejG4Gx1MCKhTdUK1sQCxsDUBpeHQcVAVcrXCXbkrCDucnMnJjS3YxrJTIi%26t%3DW1dCFBBFC1pXUwkEAEAdQFkJBVsVBRsBXB9SCltXWwg%253D&srcsubj=&type=bkbuy&subject=26356948
# Indexinghttps://book.douban.com/subject/27028847/
# Indexinghttps://book.douban.com/subject/27046739/?icn=index-latestbook-subject
# Indexinghttps://read.douban.com/ebooks/category/all/?sort=top&dcs=book-hot&dcm=douban&dct=read-more
# Indexinghttps://book.douban.com/tag/股票
# Indexinghttps://book.douban.com/cart/
# Indexinghttps://book.douban.com/tag/家居
# Indexinghttps://book.douban.com/tag/随笔
# Indexinghttps://book.douban.com/tag/交互设计
# Indexinghttps://book.douban.com/chart?subcat=F&icn=index-topchart-fiction
# Indexinghttps://book.douban.com/subject/10554308/
# Indexinghttps://book.douban.com/subject/6388661/?icn=index-book250-subject
# Indexinghttps://book.douban.com/review/8545597/?icn=index-topchart-subject
# Indexinghttps://ypy.douban.com
# Indexinghttps://book.douban.com/subject/1013129/?icn=index-book250-subject
# Indexinghttps://site.douban.com/book/
# Indexinghttps://read.douban.com/ebook/35051471/?dcs=book-hot&dcm=douban&dct=read-subject
# Indexinghttps://book.douban.com/subject/1770782/
# Indexinghttps://www.douban.com/doubanapp/
# Indexinghttps://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=iOS
# Indexinghttps://read.douban.com/ebooks/?dcs=book-nav&dcm=douban
# Indexinghttps://book.douban.com/subject/5431784/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/subject/26870453/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/link2/?pre=0&vendor=jingdong&srcpage=bestseller&price=2810&pos=7&url=http%3A%2F%2Funion-click.jd.com%2Fjdc%3Fe%3D%26p%3DAyIOZR5aEQISA1AYUyUCEQZcGlgVBiJDCkMFSjJLQhBaUAscSkIBR0ROVw1VC0dFFQETDlQYWxEdS0IJRmtcRlZeLm9cdWBmAF1TGHYAaUIdXhN1Dh5pVhpbEx4TAEkaXQQBEAxVHlAVCiIAUBxdEgsRAGUbXxQGFjdlG1olUHzf462DsLMO0%252F%252BUjp2VIgZlG14dBRsCXB5fHQobA2Uca8yCpdH3iYKLiMePwitrJTI%253D%26t%3DW1dCFBBFC1pXUwkEAEAdQFkJBVsWAxsGVhtfCltXWwg%253D&srcsubj=&type=bkbuy&subject=27028847
# Indexinghttps://read.douban.com/ebook/3021999/?dcs=book-hot&dcm=douban&dct=read-subject
# Indexinghttps://book.douban.com/tag/设计
# Indexinghttps://book.douban.com/top250?icn=index-book250-all
# Indexinghttps://book.douban.com/subject/27021974/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/link2/?pre=0&vendor=dangdang&srcpage=bestseller&price=3140&pos=6&url=http%3A%2F%2Funion.dangdang.com%2Ftransfer.php%3Ffrom%3DP-306226-0-s11637889%26backurl%3Dhttp%3A%2F%2Fproduct.dangdang.com%2Fproduct.aspx%3Fproduct_id%3D22864933&srcsubj=&type=bkbuy&subject=11637889
# Indexinghttps://book.douban.com/link2/?pre=0&vendor=jingdong&srcpage=bestseller&price=5080&pos=9&url=http%3A%2F%2Funion-click.jd.com%2Fjdc%3Fe%3D%26p%3DAyIOZR5aEQISA1AYUyUCEgFVGFkdASJDCkMFSjJLQhBaUAscSkIBR0ROVw1VC0dFFQIUB1YZUxYdS0IJRmsPAmlCHRtBFmFgfSF9DkAGc1ISbwVTDh43Uh5cEwUbBFIrWxEDFgNlK1sUMkBpja3tzaejG4Gx1MCKhTdUK1sQCxsDUBldEwMWBFQrXCXbkrCDucnMnJjS3YxrJTIi%26t%3DW1dCFBBFC1pXUwkEAEAdQFkJBVsVBBIEVxNYCltXWwg%253D&srcsubj=&type=bkbuy&subject=26670709
# Indexinghttps://book.douban.com/link2/?pre=0&vendor=dangdang&srcpage=bestseller&price=6900&pos=7&url=http%3A%2F%2Funion.dangdang.com%2Ftransfer.php%3Ffrom%3DP-306226-0-s26738072%26backurl%3Dhttp%3A%2F%2Fproduct.dangdang.com%2Fproduct.aspx%3Fproduct_id%3D23808035&srcsubj=&type=bkbuy&subject=26738072
# Indexinghttps://www.douban.com/about
# Indexinghttps://www.douban.com/about?policy=disclaimer
# Indexinghttps://book.douban.com/subject/27046066/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/tag/哲学
# Indexinghttps://book.douban.com/subject/1770782/?icn=index-book250-subject
# Indexinghttps://market.douban.com/book/?utm_campaign=book_freyr_section&utm_source=douban&utm_medium=pc_web
# Indexinghttps://book.douban.com/library_invitation
# Indexinghttps://book.douban.com/review/8556897/?icn=index-topchart-subject
# Indexinghttps://www.douban.com/doubanapp/app?channel=qipao
# Indexinghttps://book.douban.com/tag/?view=type&icn=index-sorttags-all
# Indexinghttps://www.douban.com/location
# Indexinghttps://book.douban.com/subject/27021786/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/subject/27039453/?icn=index-latestbook-subject
# Indexinghttps://read.douban.com/ebook/33431245/?dcs=book-hot&dcm=douban&dct=read-subject
# Indexinghttps://book.douban.com/tag/童话
# Indexinghttps://book.douban.com/tag/言情
# Indexinghttps://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=Android
# Indexinghttps://music.douban.com
# Indexinghttps://read.douban.com/ebook/24787676/?dcs=book-hot&dcm=douban&dct=read-subject
# Indexinghttps://book.douban.com/tag/营销
# Indexinghttps://book.douban.com/tag/名著
# Indexinghttps://book.douban.com/subject/27039964/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/subject/27041650/?icn=index-editionrecommend
# Indexinghttps://book.douban.com/subject/27013663/?icn=index-topchart-subject
# Indexinghttps://www.douban.com/people/4385493/
# Indexinghttps://book.douban.com/subject/26610864/
# Indexinghttps://book.douban.com/subject/26853356/?icn=index-topchart-subject
# Indexinghttps://book.douban.com/review/8555888/?icn=index-topchart-subject
# Indexinghttps://book.douban.com/review/8618706/
# Indexinghttps://book.douban.com/review/best/
# Indexinghttps://book.douban.com/subject/25862578/
# Indexinghttps://book.douban.com/tag/旅行
# Indexinghttps://book.douban.com/annual2016/?source=navigation
# Indexinghttps://book.douban.com/subject/27012054/?icn=index-topchart-subject
# Indexinghttps://book.douban.com/subject/1080309/?icn=index-book250-subject
# Indexinghttps://book.douban.com/link2/?pre=0&vendor=jingdong&srcpage=bestseller&price=3000&pos=2&url=http%3A%2F%2Funion-click.jd.com%2Fjdc%3Fe%3D%26p%3DAyIOZR5aEQISA1AYUyUCEgZcG1wdBiJDCkMFSjJLQhBaUAscSkIBR0ROVw1VC0dFFQITDlUcUxEdS0IJRmtGBFtnNEw8UWBlcVdkCGsYV1A3ZDJlDh43Uh5cEwUbBFIrWxEDFgNlK1sUMkBpja3tzaejG4Gx1MCKhTdUK1sQCxsDUBpcHQoWBFcrXCXbkrCDucnMnJjS3YxrJTIi%26t%3DW1dCFBBFC1pXUwkEAEAdQFkJBVsVAxsHUhNfCltXWwg%253D&srcsubj=&type=bkbuy&subject=10564071
# Indexinghttps://market.douban.com/book/ruhuazaiye?utm_campaign=book_freyr_section&utm_source=douban&utm_medium=pc_web
# Indexinghttps://book.douban.com/tag/通信
# Indexinghttps://book.douban.com/tag/小说
# Indexinghttps://book.douban.com/tag/神经网络
# Indexinghttps://book.douban.com/subject/27037149/?icn=index-latestbook-subject
# Indexinghttps://www.douban.com/hnypt/variformcyst.py
# Indexinghttps://book.douban.com/tag/理财
# Indexinghttps://book.douban.com/subject/26963321/?icn=index-topchart-subject
# Indexinghttps://book.douban.com/tag/日本文学
# Indexinghttps://www.douban.com/accounts/login?source=book
# Indexinghttps://read.douban.com/?dcs=top-nav&dcm=douban
# Indexinghttps://book.douban.com/subject/26805837/
# Indexinghttps://book.douban.com/subject/26738072/
# Indexinghttps://book.douban.com/review/8450484/?icn=index-topchart-subject
# Indexinghttps://book.douban.com/subject/27042830/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/link2/?pre=0&vendor=jingdong&srcpage=bestseller&price=2940&pos=4&url=http%3A%2F%2Funion-click.jd.com%2Fjdc%3Fe%3D%26p%3DAyIOZR5aEQISA1AYUyUCEgJRGFIQAyJDCkMFSjJLQhBaUAscSkIBR0ROVw1VC0dFFQIXA1YSXhQdS0IJRmt3X0RALUYbTmFGVzRTE0VQSUBLUF5TDh43Uh5cEwUbBFIrWxEDFgNlK1sUMkBpja3tzaejG4Gx1MCKhTdUK1sQCxsDUBpfEQAXD1YrXCXbkrCDucnMnJjS3YxrJTIi%26t%3DW1dCFBBFC1pXUwkEAEAdQFkJBVsVBxYEXB5aCltXWwg%253D&srcsubj=&type=bkbuy&subject=25862578
# Indexinghttps://book.douban.com/subject/27055905/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/subject/4908885/?icn=index-book250-subject
# Indexinghttps://dongxi.douban.com/?dcs=top-nav&dcm=douban
# Indexinghttp://weibo.com/doubandushu
# Indexinghttps://book.douban.com/tag/管理
# Indexinghttps://book.douban.com/tag/互联网
# Indexinghttps://book.douban.com/link2/?pre=0&vendor=dangdang&srcpage=bestseller&price=2730&pos=5&url=http%3A%2F%2Funion.dangdang.com%2Ftransfer.php%3Ffrom%3DP-306226-0-s10554308%26backurl%3Dhttp%3A%2F%2Fproduct.dangdang.com%2Fproduct.aspx%3Fproduct_id%3D22935553&srcsubj=&type=bkbuy&subject=10554308
# Indexinghttps://book.douban.com/subject/27045129/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/subject/27055849/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/tag/?view=type&icn=index-sorttags-hot
# Indexinghttps://book.douban.com/subject/26712441/?icn=index-latestbook-subject
# Indexinghttps://market.douban.com/book/busiyi?utm_campaign=book_freyr_section&utm_source=douban&utm_medium=pc_web
# Indexinghttps://book.douban.com/subject/26670709/
# Indexinghttps://book.douban.com/tag/港台
# Indexinghttps://www.douban.com/people/48051798/
# Indexinghttps://book.douban.com/subject/27017251/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/subject/10564071/
# Indexinghttps://read.douban.com/ebook/32433764/?dcs=book-hot&dcm=douban&dct=read-subject
# Indexinghttps://book.douban.com/subject/27024106/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/subject/26356948/
# Indexinghttps://book.douban.com/subject/27034332/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/link2/?pre=0&vendor=jingdong&srcpage=bestseller&price=2260&pos=1&url=http%3A%2F%2Funion-click.jd.com%2Fjdc%3Fe%3D%26p%3DAyIOZR5aEQISA1AYUyUCEgFRHVgUByJDCkMFSjJLQhBaUAscSkIBR0ROVw1VC0dFFQIUA1MYWhAdS0IJRmsSVEljCGxZE2BmBAtcAWV1G1ssZVtDDh43Uh5cEwUbBFIrWxEDFgNlK1sUMkBpja3tzaejG4Gx1MCKhTdUK1sQCxsDUBpeEgMUBl0rXCXbkrCDucnMnJjS3YxrJTIi%26t%3DW1dCFBBFC1pXUwkEAEAdQFkJBVsVBBYBVhpeCltXWwg%253D&srcsubj=&type=bkbuy&subject=26610864
# Indexinghttps://book.douban.com/subject/26939969/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/tag/职场
# Indexinghttps://book.douban.com/tag/科幻
# Indexinghttps://book.douban.com/subject/27056409/?icn=index-latestbook-subject
# Indexinghttps://www.douban.com/about?topic=contactus
# Indexinghttps://www.douban.com
# Indexinghttps://book.douban.com/review/8542286/?icn=index-topchart-subject
# Indexinghttps://book.douban.com/subject/26802388/
# Indexinghttps://market.douban.com/book/talese?utm_campaign=book_freyr_section&utm_source=douban&utm_medium=pc_web
# Indexinghttps://book.douban.com/tag/灵修
# Indexinghttps://book.douban.com/tag/绘本
# Indexinghttps://book.douban.com/tag/诗歌
# Indexinghttps://book.douban.com/link2/?pre=0&vendor=dangdang&srcpage=bestseller&price=5510&pos=8&url=http%3A%2F%2Funion.dangdang.com%2Ftransfer.php%3Ffrom%3DP-306226-0-s10517238%26backurl%3Dhttp%3A%2F%2Fproduct.dangdang.com%2Fproduct.aspx%3Fproduct_id%3D22616096&srcsubj=&type=bkbuy&subject=10517238
# Indexinghttps://douban.fm/?from_=shire_top_nav
# Indexinghttps://book.douban.com/subject/27012339/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/link2/?pre=0&vendor=jingdong&srcpage=bestseller&price=2800&pos=8&url=http%3A%2F%2Funion-click.jd.com%2Fjdc%3Fe%3D%26p%3DAyIOZR5aEQISA1AYUyUCEg9QG10WCyJDCkMFSjJLQhBaUAscSkIBR0ROVw1VC0dFFQIaAlUdWBwdS0IJRmtsSkRVME0ZRWF0YQoTXmV4EBkWbVhTDh43Uh5cEwUbBFIrWxEDFgNlK1sUMkBpja3tzaejG4Gx1MCKhTdUK1sQCxsDUBpcEQQWDlMrXCXbkrCDucnMnJjS3YxrJTIi%26t%3DW1dCFBBFC1pXUwkEAEAdQFkJBVsVChcHUxhSCltXWwg%253D&srcsubj=&type=bkbuy&subject=26802388
# Indexinghttps://book.douban.com/subject/27045564/?icn=index-latestbook-subject
# Indexinghttps://market.douban.com/book/baiguiyexing?utm_campaign=book_freyr_section&utm_source=douban&utm_medium=pc_web
# Indexinghttps://moment.douban.com
# Indexinghttps://www.douban.com/group
# Indexinghttps://book.douban.com/tag/电影
# Indexinghttps://book.douban.com/tag/编程
# Indexinghttps://market.douban.com/book/shanzhisiji?utm_campaign=book_freyr_section&utm_source=douban&utm_medium=pc_web
# Indexinghttps://book.douban.com/subject/27055728/?icn=index-editionrecommend
# Indexinghttps://www.douban.com/doubanapp/app?channel=top-nav
# Indexinghttps://book.douban.com/subject/27037148/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/subject/27029890/?icn=index-topchart-subject
# Indexinghttps://book.douban.com/tag/励志
# Indexinghttps://book.douban.com/latest?icn=index-latestbook-all
# Indexinghttps://read.douban.com/ebooks?dcs=book-intro&dcm=douban
# Indexinghttps://book.douban.com/link2/?pre=0&vendor=jingdong&srcpage=bestseller&price=2510&pos=3&url=http%3A%2F%2Funion-click.jd.com%2Fjdc%3Fe%3D%26p%3DAyIOZR5aEQISA1AYUyUCEg9XHVwXCyJDCkMFSjJLQhBaUAscSkIBR0ROVw1VC0dFFQIaBVMcWRwdS0IJRmtcemRcT24FUmETYS9mEmBnFXAnWB9lDh43Uh5cEwUbBFIrWxEDFgNlK1sUMkBpja3tzaejG4Gx1MCKhTdUK1sQCxsDUBtdFgAbBlcrXCXbkrCDucnMnJjS3YxrJTIi%26t%3DW1dCFBBFC1pXUwkEAEAdQFkJBVsVChABUhlSCltXWwg%253D&srcsubj=&type=bkbuy&subject=26805837
# Indexinghttps://book.douban.com/link2/?pre=0&vendor=dangdang&srcpage=bestseller&price=1989&pos=3&url=http%3A%2F%2Funion.dangdang.com%2Ftransfer.php%3Ffrom%3DP-306226-0-s26666472%26backurl%3Dhttp%3A%2F%2Fproduct.dangdang.com%2Fproduct.aspx%3Fproduct_id%3D23822200&srcsubj=&type=bkbuy&subject=26666472
# Indexinghttps://book.douban.com/subject/6710437/?icn=index-book250-subject
# Indexinghttps://www.douban.com/partner/
# Indexinghttps://book.douban.com/tag/建筑
# Indexinghttps://book.douban.com/subject/27005756/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/tag/音乐
# Indexinghttps://book.douban.com/subject/10517238/
# Indexinghttps://book.douban.com/subject/26978921/
# Indexinghttps://book.douban.com/subject/26972277/
# Indexinghttps://book.douban.com/tag/奇幻
# Indexinghttps://book.douban.com/subject/26940525/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/link2/?pre=0&vendor=dangdang&srcpage=bestseller&price=2340&pos=10&url=http%3A%2F%2Funion.dangdang.com%2Ftransfer.php%3Ffrom%3DP-306226-0-s26972277%26backurl%3Dhttp%3A%2F%2Fproduct.dangdang.com%2Fproduct.aspx%3Fproduct_id%3D24188188&srcsubj=&type=bkbuy&subject=26972277
# Indexinghttps://book.douban.com/subject/27037182/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/review/8424009/?icn=index-topchart-subject
# Indexinghttps://book.douban.com/tag/商业
# Indexinghttps://www.douban.com/people/krisshen/
# Indexinghttps://book.douban.com/review/8618701/
# Indexinghttps://book.douban.com/subject/27064644/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/subject/26962683/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/review/8514711/?icn=index-topchart-subject
# Indexinghttps://book.douban.com/review/8583202/
# Indexinghttps://book.douban.com/tag/教育
# Indexinghttps://movie.douban.com
# Indexinghttps://book.douban.com/subject/27017794/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/subject/26487578/?icn=index-latestbook-subject
# Indexinghttps://read.douban.com/ebook/35023547/?dcs=book-hot&dcm=douban&dct=read-subject
# Indexinghttps://book.douban.com/review/8603586/
# Indexinghttps://book.douban.com/tag/算法
# Indexinghttps://book.douban.com/link2/?pre=0&vendor=jingdong&srcpage=bestseller&price=2420&pos=10&url=http%3A%2F%2Funion-click.jd.com%2Fjdc%3Fe%3D%26p%3DAyIOZR5aEQISA1AYUyUCEgBTEloUBCJDCkMFSjJLQhBaUAscSkIBR0ROVw1VC0dFFQIVAVwaWhMdS0IJRmtGRHFcM3ApUWJpcT5QLVFgagE3aVlDDh43Uh5cEwUbBFIrWxEDFgNlK1sUMkBpja3tzaejG4Gx1MCKhTdUK1sQCxsDUBpcEwYRBlQrXCXbkrCDucnMnJjS3YxrJTIi%26t%3DW1dCFBBFC1pXUwkEAEAdQFkJBVsVBRQOVBpdCltXWwg%253D&srcsubj=&type=bkbuy&subject=26340138
# Indexinghttps://book.douban.com/review/8544907/?icn=index-topchart-subject
# Indexinghttps://book.douban.com/tag/金融
# Indexinghttps://book.douban.com/subject/26647769/
# Indexinghttps://help.douban.com/?app=book
# Indexinghttps://book.douban.com/review/8618835/
# Indexinghttps://book.douban.com/review/8503927/?icn=index-topchart-subject
# Indexinghttps://book.douban.com/link2/?pre=0&vendor=jingdong&srcpage=bestseller&price=2360&pos=6&url=http%3A%2F%2Funion-click.jd.com%2Fjdc%3Fe%3D%26p%3DAyIOZR5aEQISA1AYUyUCEg9dHVwVBiJDCkMFSjJLQhBaUAscSkIBR0ROVw1VC0dFFQIaD1McWxEdS0IJRmtKAUsAVVIeZ2AadSNCHAtjUHwyYyRDDh43Uh5cEwUbBFIrWxEDFgNlK1sUMkBpja3tzaejG4Gx1MCKhTdUK1sQCxsDUBhaEwYWBVIrXCXbkrCDucnMnJjS3YxrJTIi%26t%3DW1dCFBBFC1pXUwkEAEAdQFkJBVsVChoBUhtfCltXWwg%253D&srcsubj=&type=bkbuy&subject=26897699
# Indexinghttps://book.douban.com/tag/武侠
# Indexinghttps://book.douban.com/tag/企业史
# Indexinghttps://book.douban.com/tag/回忆录
# Indexinghttps://book.douban.com/tag/科普
# Indexinghttps://read.douban.com/ebook/5083852/?dcs=book-hot&dcm=douban&dct=read-subject
# Indexinghttps://www.douban.com/people/samsa/
# Indexinghttps://book.douban.com/tag/经济学
# Indexinghttps://book.douban.com/tag/青春
# Indexinghttps://book.douban.com/subject/27053166/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/subject/26897699/
# Indexinghttps://read.douban.com/ebook/34907446/?dcs=book-hot&dcm=douban&dct=read-subject
# Indexinghttps://market.douban.com/book?utm_campaign=book_nav_freyr&utm_source=douban&utm_medium=pc_web
# Indexinghttps://book.douban.com/tag/推理
# Indexinghttps://book.douban.com/subject/4953695/?icn=index-book250-subject
# Indexinghttps://book.douban.com/subject/27042365/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/subject/11637889/
# Indexinghttps://book.douban.com/tag/传记
# Indexinghttps://book.douban.com/subject/27000152/?icn=index-topchart-subject
# Indexinghttps://book.douban.com/subject/27043711/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/review/8512322/?icn=index-topchart-subject
# Indexinghttps://book.douban.com/subject/26975609/?icn=index-topchart-subject
# Indexinghttps://book.douban.com/subject/27053755/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/subject/27001165/?icn=index-latestbook-subject
# Indexinghttps://book.douban.com/link2/?pre=0&vendor=dangdang&srcpage=bestseller&price=1450&pos=4&url=http%3A%2F%2Funion.dangdang.com%2Ftransfer.php%3Ffrom%3DP-306226-0-s1770782%26backurl%3Dhttp%3A%2F%2Fproduct.dangdang.com%2Fproduct.aspx%3Fproduct_id%3D23274638&srcsubj=&type=bkbuy&subject=1770782
# Indexinghttps://read.douban.com/ebook/34384688/?dcs=book-hot&dcm=douban&dct=read-subject
# Indexinghttps://book.douban.com/subject/26893260/?icn=index-topchart-subject

# %% [markdown]
# ## 查询
# 现在我们开始创建searcher类，其功能是通过查询数据库进行全文搜索

# %%
class searcher:
    def __init__(self,dbname):
        self.con=sqlite3.connect(dbname)
    
    def __del__(self):
        self.con.close()

# %% [markdown]
# 增加getmatchrows函数，其功能是接收一个查询字符串，将其拆分为多个单词，然后构造一个SQL查询

# %%
class searcher:
    def __init__(self,dbname):
        self.con=sqlite3.connect(dbname)
    
    def __del__(self):
        self.con.close()
        
    def getmatchrows(self,q):
        # 构造查询的字符串
        fieldlist='w0.urlid'
        tablelist=''
        clauselist=''
        wordids=[]
        
        # 根据空格拆分单词
        words=q.split(' ')  
        tablenumber=0

        for word in words:
            # 获取单词的ID
            wordrow=self.con.execute("select rowid from wordlist where word='%s'" % word).fetchone()
            if wordrow!=None:
                wordid=wordrow[0]
                wordids.append(wordid)
                if tablenumber>0:
                    tablelist+=','
                    clauselist+=' and '
                    clauselist+='w%d.urlid=w%d.urlid and ' % (tablenumber-1,tablenumber)
                fieldlist+=',w%d.location' % tablenumber
                tablelist+='wordlocation w%d' % tablenumber      
                clauselist+='w%d.wordid=%d' % (tablenumber,wordid)
                tablenumber+=1

        # 根据各个组分，建立查询
        fullquery='select %s from %s where %s' % (fieldlist,tablelist,clauselist)
        print(fullquery)
        cur=self.con.execute(fullquery)
        rows=[row for row in cur]

        return rows,wordids

# %%
e=searcher('searchindex.db')
e.getmatchrows('functional programming')
# Out:
# select w0.urlid,w0.location,w1.location from wordlocation w0,wordlocation w1 where w0.wordid=145 and w0.urlid=w1.urlid and w1.wordid=19
# ([(1, 327, 23),
#   (1, 327, 162),
#   (1, 327, 243),
#   (1, 327, 261),
#   (1, 327, 269),
#   (1, 327, 436),
#   (1, 327, 953),
#   (1, 327, 1123),
#   (1, 327, 1159),
#   (1, 327, 1172),
#   (1, 327, 1230),
#   (1, 327, 1240),
#   (1, 327, 1258),
#   (1, 327, 1304),
#   (1, 327, 1346),
#   (1, 327, 1351),
#   (1, 327, 1407),
#   (1, 327, 1410),
#   (1, 327, 1603),
#   (1, 327, 1668),
#   (1, 327, 1681),
#   (1, 327, 1687),
#   (1, 327, 1690),
#   (1, 327, 1715),
#   (1, 327, 1745),
#   (1, 327, 1778),
#   (1, 327, 1857),
#   (1, 327, 1897),
#   (1, 327, 1927),
#   (1, 327, 1949),
#   (1, 327, 2042),
#   (1, 327, 2109),
#   (1, 327, 2119),
#   (1, 327, 2151),
#   (1, 327, 2386),
#   (1, 327, 2453),
#   (1, 327, 2464),
#   (1, 327, 2656),
#   (1, 327, 2761),
#   (1, 327, 2766),
#   (1, 327, 2800),
#   (1, 327, 2855),
#   (1, 327, 2995),
#   (1, 327, 3096),
#   (1, 327, 3172),
#   (1, 327, 3440),
#   (1, 327, 3450),
#   (1, 327, 3465),
#   (1, 327, 3770),
#   (1, 327, 3801),
#   (1, 327, 3804),
#   (1, 327, 3809),
#   (1, 327, 3885),
#   (1, 327, 3888),
#   (1, 327, 4041),
#   (1, 327, 4089),
#   (1, 1591, 23),
#   (1, 1591, 162),
#   (1, 1591, 243),
#   (1, 1591, 261),
#   (1, 1591, 269),
#   (1, 1591, 436),
#   (1, 1591, 953),
#   (1, 1591, 1123),
#   (1, 1591, 1159),
#   (1, 1591, 1172),
#   (1, 1591, 1230),
#   (1, 1591, 1240),
#   (1, 1591, 1258),
#   (1, 1591, 1304),
#   (1, 1591, 1346),
#   (1, 1591, 1351),
#   (1, 1591, 1407),
#   (1, 1591, 1410),
#   (1, 1591, 1603),
#   (1, 1591, 1668),
#   (1, 1591, 1681),
#   (1, 1591, 1687),
#   (1, 1591, 1690),
#   (1, 1591, 1715),
#   (1, 1591, 1745),
#   (1, 1591, 1778),
#   (1, 1591, 1857),
#   (1, 1591, 1897),
#   (1, 1591, 1927),
#   (1, 1591, 1949),
#   (1, 1591, 2042),
#   (1, 1591, 2109),
#   (1, 1591, 2119),
#   (1, 1591, 2151),
#   (1, 1591, 2386),
#   (1, 1591, 2453),
#   (1, 1591, 2464),
#   (1, 1591, 2656),
#   (1, 1591, 2761),
#   (1, 1591, 2766),
#   (1, 1591, 2800),
#   (1, 1591, 2855),
#   (1, 1591, 2995),
#   (1, 1591, 3096),
#   (1, 1591, 3172),
#   (1, 1591, 3440),
#   (1, 1591, 3450),
#   (1, 1591, 3465),
#   (1, 1591, 3770),
#   (1, 1591, 3801),
#   (1, 1591, 3804),
#   (1, 1591, 3809),
#   (1, 1591, 3885),
#   (1, 1591, 3888),
#   (1, 1591, 4041),
#   (1, 1591, 4089),
#   (1, 1711, 23),
#   (1, 1711, 162),
#   (1, 1711, 243),
#   (1, 1711, 261),
#   (1, 1711, 269),
#   (1, 1711, 436),
#   (1, 1711, 953),
#   (1, 1711, 1123),
#   (1, 1711, 1159),
#   (1, 1711, 1172),
#   (1, 1711, 1230),
#   (1, 1711, 1240),
#   (1, 1711, 1258),
#   (1, 1711, 1304),
#   (1, 1711, 1346),
#   (1, 1711, 1351),
#   (1, 1711, 1407),
#   (1, 1711, 1410),
#   (1, 1711, 1603),
#   (1, 1711, 1668),
#   (1, 1711, 1681),
#   (1, 1711, 1687),
#   (1, 1711, 1690),
#   (1, 1711, 1715),
#   (1, 1711, 1745),
#   (1, 1711, 1778),
#   (1, 1711, 1857),
#   (1, 1711, 1897),
#   (1, 1711, 1927),
#   (1, 1711, 1949),
#   (1, 1711, 2042),
#   (1, 1711, 2109),
#   (1, 1711, 2119),
#   (1, 1711, 2151),
#   (1, 1711, 2386),
#   (1, 1711, 2453),
#   (1, 1711, 2464),
#   (1, 1711, 2656),
#   (1, 1711, 2761),
#   (1, 1711, 2766),
#   (1, 1711, 2800),
#   (1, 1711, 2855),
#   (1, 1711, 2995),
#   (1, 1711, 3096),
#   (1, 1711, 3172),
#   (1, 1711, 3440),
#   (1, 1711, 3450),
#   (1, 1711, 3465),
#   (1, 1711, 3770),
#   (1, 1711, 3801),
#   (1, 1711, 3804),
#   (1, 1711, 3809),
#   (1, 1711, 3885),
#   (1, 1711, 3888),
#   (1, 1711, 4041),
#   (1, 1711, 4089),
#   (1, 1722, 23),
#   (1, 1722, 162),
#   (1, 1722, 243),
#   (1, 1722, 261),
#   (1, 1722, 269),
#   (1, 1722, 436),
#   (1, 1722, 953),
#   (1, 1722, 1123),
#   (1, 1722, 1159),
#   (1, 1722, 1172),
#   (1, 1722, 1230),
#   (1, 1722, 1240),
#   (1, 1722, 1258),
#   (1, 1722, 1304),
#   (1, 1722, 1346),
#   (1, 1722, 1351),
#   (1, 1722, 1407),
#   (1, 1722, 1410),
#   (1, 1722, 1603),
#   (1, 1722, 1668),
#   (1, 1722, 1681),
#   (1, 1722, 1687),
#   (1, 1722, 1690),
#   (1, 1722, 1715),
#   (1, 1722, 1745),
#   (1, 1722, 1778),
#   (1, 1722, 1857),
#   (1, 1722, 1897),
#   (1, 1722, 1927),
#   (1, 1722, 1949),
#   (1, 1722, 2042),
#   (1, 1722, 2109),
#   (1, 1722, 2119),
#   (1, 1722, 2151),
#   (1, 1722, 2386),
#   (1, 1722, 2453),
#   (1, 1722, 2464),
#   (1, 1722, 2656),
#   (1, 1722, 2761),
#   (1, 1722, 2766),
#   (1, 1722, 2800),
#   (1, 1722, 2855),
#   (1, 1722, 2995),
#   (1, 1722, 3096),
#   (1, 1722, 3172),
#   (1, 1722, 3440),
#   (1, 1722, 3450),
#   (1, 1722, 3465),
#   (1, 1722, 3770),
#   (1, 1722, 3801),
#   (1, 1722, 3804),
#   (1, 1722, 3809),
#   (1, 1722, 3885),
#   (1, 1722, 3888),
#   (1, 1722, 4041),
#   (1, 1722, 4089),
#   (1, 1849, 23),
#   (1, 1849, 162),
#   (1, 1849, 243),
#   (1, 1849, 261),
#   (1, 1849, 269),
#   (1, 1849, 436),
#   (1, 1849, 953),
#   (1, 1849, 1123),
#   (1, 1849, 1159),
#   (1, 1849, 1172),
#   (1, 1849, 1230),
#   (1, 1849, 1240),
#   (1, 1849, 1258),
#   (1, 1849, 1304),
#   (1, 1849, 1346),
#   (1, 1849, 1351),
#   (1, 1849, 1407),
#   (1, 1849, 1410),
#   (1, 1849, 1603),
#   (1, 1849, 1668),
#   (1, 1849, 1681),
#   (1, 1849, 1687),
#   (1, 1849, 1690),
#   (1, 1849, 1715),
#   (1, 1849, 1745),
#   (1, 1849, 1778),
#   (1, 1849, 1857),
#   (1, 1849, 1897),
#   (1, 1849, 1927),
#   (1, 1849, 1949),
#   (1, 1849, 2042),
#   (1, 1849, 2109),
#   (1, 1849, 2119),
#   (1, 1849, 2151),
#   (1, 1849, 2386),
#   (1, 1849, 2453),
#   (1, 1849, 2464),
#   (1, 1849, 2656),
#   (1, 1849, 2761),
#   (1, 1849, 2766),
#   (1, 1849, 2800),
#   (1, 1849, 2855),
#   (1, 1849, 2995),
#   (1, 1849, 3096),
#   (1, 1849, 3172),
#   (1, 1849, 3440),
#   (1, 1849, 3450),
#   (1, 1849, 3465),
#   (1, 1849, 3770),
#   (1, 1849, 3801),
#   (1, 1849, 3804),
#   (1, 1849, 3809),
#   (1, 1849, 3885),
#   (1, 1849, 3888),
#   (1, 1849, 4041),
#   (1, 1849, 4089),
#   (1, 1854, 23),
#   (1, 1854, 162),
#   (1, 1854, 243),
#   (1, 1854, 261),
#   (1, 1854, 269),
#   (1, 1854, 436),
#   (1, 1854, 953),
#   (1, 1854, 1123),
#   (1, 1854, 1159),
#   (1, 1854, 1172),
#   (1, 1854, 1230),
#   (1, 1854, 1240),
#   (1, 1854, 1258),
#   (1, 1854, 1304),
#   (1, 1854, 1346),
#   (1, 1854, 1351),
#   (1, 1854, 1407),
#   (1, 1854, 1410),
#   (1, 1854, 1603),
#   (1, 1854, 1668),
#   (1, 1854, 1681),
#   (1, 1854, 1687),
#   (1, 1854, 1690),
#   (1, 1854, 1715),
#   (1, 1854, 1745),
#   (1, 1854, 1778),
#   (1, 1854, 1857),
#   (1, 1854, 1897),
#   (1, 1854, 1927),
#   (1, 1854, 1949),
#   (1, 1854, 2042),
#   (1, 1854, 2109),
#   (1, 1854, 2119),
#   (1, 1854, 2151),
#   (1, 1854, 2386),
#   (1, 1854, 2453),
#   (1, 1854, 2464),
#   (1, 1854, 2656),
#   (1, 1854, 2761),
#   (1, 1854, 2766),
#   (1, 1854, 2800),
#   (1, 1854, 2855),
#   (1, 1854, 2995),
#   (1, 1854, 3096),
#   (1, 1854, 3172),
#   (1, 1854, 3440),
#   (1, 1854, 3450),
#   (1, 1854, 3465),
#   (1, 1854, 3770),
#   (1, 1854, 3801),
#   (1, 1854, 3804),
#   (1, 1854, 3809),
#   (1, 1854, 3885),
#   (1, 1854, 3888),
#   (1, 1854, 4041),
#   (1, 1854, 4089),
#   (1, 1856, 23),
#   (1, 1856, 162),
#   (1, 1856, 243),
#   (1, 1856, 261),
#   (1, 1856, 269),
#   (1, 1856, 436),
#   (1, 1856, 953),
#   (1, 1856, 1123),
#   (1, 1856, 1159),
#   (1, 1856, 1172),
#   (1, 1856, 1230),
#   (1, 1856, 1240),
#   (1, 1856, 1258),
#   (1, 1856, 1304),
#   (1, 1856, 1346),
#   (1, 1856, 1351),
#   (1, 1856, 1407),
#   (1, 1856, 1410),
#   (1, 1856, 1603),
#   (1, 1856, 1668),
#   (1, 1856, 1681),
#   (1, 1856, 1687),
#   (1, 1856, 1690),
#   (1, 1856, 1715),
#   (1, 1856, 1745),
#   (1, 1856, 1778),
#   (1, 1856, 1857),
#   (1, 1856, 1897),
#   (1, 1856, 1927),
#   (1, 1856, 1949),
#   (1, 1856, 2042),
#   (1, 1856, 2109),
#   (1, 1856, 2119),
#   (1, 1856, 2151),
#   (1, 1856, 2386),
#   (1, 1856, 2453),
#   (1, 1856, 2464),
#   (1, 1856, 2656),
#   (1, 1856, 2761),
#   (1, 1856, 2766),
#   (1, 1856, 2800),
#   (1, 1856, 2855),
#   (1, 1856, 2995),
#   (1, 1856, 3096),
#   (1, 1856, 3172),
#   (1, 1856, 3440),
#   (1, 1856, 3450),
#   (1, 1856, 3465),
#   (1, 1856, 3770),
#   (1, 1856, 3801),
#   (1, 1856, 3804),
#   (1, 1856, 3809),
#   (1, 1856, 3885),
#   (1, 1856, 3888),
#   (1, 1856, 4041),
#   (1, 1856, 4089),
#   (1, 1869, 23),
#   (1, 1869, 162),
#   (1, 1869, 243),
#   (1, 1869, 261),
#   (1, 1869, 269),
#   (1, 1869, 436),
#   (1, 1869, 953),
#   (1, 1869, 1123),
#   (1, 1869, 1159),
#   (1, 1869, 1172),
#   (1, 1869, 1230),
#   (1, 1869, 1240),
#   (1, 1869, 1258),
#   (1, 1869, 1304),
#   (1, 1869, 1346),
#   (1, 1869, 1351),
#   (1, 1869, 1407),
#   (1, 1869, 1410),
#   (1, 1869, 1603),
#   (1, 1869, 1668),
#   (1, 1869, 1681),
#   (1, 1869, 1687),
#   (1, 1869, 1690),
#   (1, 1869, 1715),
#   (1, 1869, 1745),
#   (1, 1869, 1778),
#   (1, 1869, 1857),
#   (1, 1869, 1897),
#   (1, 1869, 1927),
#   (1, 1869, 1949),
#   (1, 1869, 2042),
#   (1, 1869, 2109),
#   (1, 1869, 2119),
#   (1, 1869, 2151),
#   (1, 1869, 2386),
#   (1, 1869, 2453),
#   (1, 1869, 2464),
#   (1, 1869, 2656),
#   (1, 1869, 2761),
#   (1, 1869, 2766),
#   (1, 1869, 2800),
#   (1, 1869, 2855),
#   (1, 1869, 2995),
#   (1, 1869, 3096),
#   (1, 1869, 3172),
#   (1, 1869, 3440),
#   (1, 1869, 3450),
#   (1, 1869, 3465),
#   (1, 1869, 3770),
#   (1, 1869, 3801),
#   (1, 1869, 3804),
#   (1, 1869, 3809),
#   (1, 1869, 3885),
#   (1, 1869, 3888),
#   (1, 1869, 4041),
#   (1, 1869, 4089),
#   (1, 1888, 23),
#   (1, 1888, 162),
#   (1, 1888, 243),
#   (1, 1888, 261),
#   (1, 1888, 269),
#   (1, 1888, 436),
#   (1, 1888, 953),
#   (1, 1888, 1123),
#   (1, 1888, 1159),
#   (1, 1888, 1172),
#   (1, 1888, 1230),
#   (1, 1888, 1240),
#   (1, 1888, 1258),
#   (1, 1888, 1304),
#   (1, 1888, 1346),
#   (1, 1888, 1351),
#   (1, 1888, 1407),
#   (1, 1888, 1410),
#   (1, 1888, 1603),
#   (1, 1888, 1668),
#   (1, 1888, 1681),
#   (1, 1888, 1687),
#   (1, 1888, 1690),
#   (1, 1888, 1715),
#   (1, 1888, 1745),
#   (1, 1888, 1778),
#   (1, 1888, 1857),
#   (1, 1888, 1897),
#   (1, 1888, 1927),
#   (1, 1888, 1949),
#   (1, 1888, 2042),
#   (1, 1888, 2109),
#   (1, 1888, 2119),
#   (1, 1888, 2151),
#   (1, 1888, 2386),
#   (1, 1888, 2453),
#   (1, 1888, 2464),
#   (1, 1888, 2656),
#   (1, 1888, 2761),
#   (1, 1888, 2766),
#   (1, 1888, 2800),
#   (1, 1888, 2855),
#   (1, 1888, 2995),
#   (1, 1888, 3096),
#   (1, 1888, 3172),
#   (1, 1888, 3440),
#   (1, 1888, 3450),
#   (1, 1888, 3465),
#   (1, 1888, 3770),
#   (1, 1888, 3801),
#   (1, 1888, 3804),
#   (1, 1888, 3809),
#   (1, 1888, 3885),
#   (1, 1888, 3888),
#   (1, 1888, 4041),
#   (1, 1888, 4089),
#   (1, 1895, 23),
#   (1, 1895, 162),
#   (1, 1895, 243),
#   (1, 1895, 261),
#   (1, 1895, 269),
#   (1, 1895, 436),
#   (1, 1895, 953),
#   (1, 1895, 1123),
#   (1, 1895, 1159),
#   (1, 1895, 1172),
#   (1, 1895, 1230),
#   (1, 1895, 1240),
#   (1, 1895, 1258),
#   (1, 1895, 1304),
#   (1, 1895, 1346),
#   (1, 1895, 1351),
#   (1, 1895, 1407),
#   (1, 1895, 1410),
#   (1, 1895, 1603),
#   (1, 1895, 1668),
#   (1, 1895, 1681),
#   (1, 1895, 1687),
#   (1, 1895, 1690),
#   (1, 1895, 1715),
#   (1, 1895, 1745),
#   (1, 1895, 1778),
#   (1, 1895, 1857),
#   (1, 1895, 1897),
#   (1, 1895, 1927),
#   (1, 1895, 1949),
#   (1, 1895, 2042),
#   (1, 1895, 2109),
#   (1, 1895, 2119),
#   (1, 1895, 2151),
#   (1, 1895, 2386),
#   (1, 1895, 2453),
#   (1, 1895, 2464),
#   (1, 1895, 2656),
#   (1, 1895, 2761),
#   (1, 1895, 2766),
#   (1, 1895, 2800),
#   (1, 1895, 2855),
#   (1, 1895, 2995),
#   (1, 1895, 3096),
#   (1, 1895, 3172),
#   (1, 1895, 3440),
#   (1, 1895, 3450),
#   (1, 1895, 3465),
#   (1, 1895, 3770),
#   (1, 1895, 3801),
#   (1, 1895, 3804),
#   (1, 1895, 3809),
#   (1, 1895, 3885),
#   (1, 1895, 3888),
#   (1, 1895, 4041),
#   (1, 1895, 4089),
#   (1, 1905, 23),
#   (1, 1905, 162),
#   (1, 1905, 243),
#   (1, 1905, 261),
#   (1, 1905, 269),
#   (1, 1905, 436),
#   (1, 1905, 953),
#   (1, 1905, 1123),
#   (1, 1905, 1159),
#   (1, 1905, 1172),
#   (1, 1905, 1230),
#   (1, 1905, 1240),
#   (1, 1905, 1258),
#   (1, 1905, 1304),
#   (1, 1905, 1346),
#   (1, 1905, 1351),
#   (1, 1905, 1407),
#   (1, 1905, 1410),
#   (1, 1905, 1603),
#   (1, 1905, 1668),
#   (1, 1905, 1681),
#   (1, 1905, 1687),
#   (1, 1905, 1690),
#   (1, 1905, 1715),
#   (1, 1905, 1745),
#   (1, 1905, 1778),
#   (1, 1905, 1857),
#   (1, 1905, 1897),
#   (1, 1905, 1927),
#   (1, 1905, 1949),
#   (1, 1905, 2042),
#   (1, 1905, 2109),
#   (1, 1905, 2119),
#   (1, 1905, 2151),
#   (1, 1905, 2386),
#   (1, 1905, 2453),
#   (1, 1905, 2464),
#   (1, 1905, 2656),
#   (1, 1905, 2761),
#   (1, 1905, 2766),
#   (1, 1905, 2800),
#   (1, 1905, 2855),
#   (1, 1905, 2995),
#   (1, 1905, 3096),
#   (1, 1905, 3172),
#   (1, 1905, 3440),
#   (1, 1905, 3450),
#   (1, 1905, 3465),
#   (1, 1905, 3770),
#   (1, 1905, 3801),
#   (1, 1905, 3804),
#   (1, 1905, 3809),
#   (1, 1905, 3885),
#   (1, 1905, 3888),
#   (1, 1905, 4041),
#   (1, 1905, 4089),
#   (1, 2507, 23),
#   (1, 2507, 162),
#   (1, 2507, 243),
#   (1, 2507, 261),
#   (1, 2507, 269),
#   (1, 2507, 436),
#   (1, 2507, 953),
#   (1, 2507, 1123),
#   (1, 2507, 1159),
#   (1, 2507, 1172),
#   (1, 2507, 1230),
#   (1, 2507, 1240),
#   (1, 2507, 1258),
#   (1, 2507, 1304),
#   (1, 2507, 1346),
#   (1, 2507, 1351),
#   (1, 2507, 1407),
#   (1, 2507, 1410),
#   (1, 2507, 1603),
#   (1, 2507, 1668),
#   (1, 2507, 1681),
#   (1, 2507, 1687),
#   (1, 2507, 1690),
#   (1, 2507, 1715),
#   (1, 2507, 1745),
#   (1, 2507, 1778),
#   (1, 2507, 1857),
#   (1, 2507, 1897),
#   (1, 2507, 1927),
#   (1, 2507, 1949),
#   (1, 2507, 2042),
#   (1, 2507, 2109),
#   (1, 2507, 2119),
#   (1, 2507, 2151),
#   (1, 2507, 2386),
#   (1, 2507, 2453),
#   (1, 2507, 2464),
#   (1, 2507, 2656),
#   (1, 2507, 2761),
#   (1, 2507, 2766),
#   (1, 2507, 2800),
#   (1, 2507, 2855),
#   (1, 2507, 2995),
#   (1, 2507, 3096),
#   (1, 2507, 3172),
#   (1, 2507, 3440),
#   (1, 2507, 3450),
#   (1, 2507, 3465),
#   (1, 2507, 3770),
#   (1, 2507, 3801),
#   (1, 2507, 3804),
#   (1, 2507, 3809),
#   (1, 2507, 3885),
#   (1, 2507, 3888),
#   (1, 2507, 4041),
#   (1, 2507, 4089),
#   (1, 2510, 23),
#   (1, 2510, 162),
#   (1, 2510, 243),
#   (1, 2510, 261),
#   (1, 2510, 269),
#   (1, 2510, 436),
#   (1, 2510, 953),
#   (1, 2510, 1123),
#   (1, 2510, 1159),
#   (1, 2510, 1172),
#   (1, 2510, 1230),
#   (1, 2510, 1240),
#   (1, 2510, 1258),
#   (1, 2510, 1304),
#   (1, 2510, 1346),
#   (1, 2510, 1351),
#   (1, 2510, 1407),
#   (1, 2510, 1410),
#   (1, 2510, 1603),
#   (1, 2510, 1668),
#   (1, 2510, 1681),
#   (1, 2510, 1687),
#   (1, 2510, 1690),
#   (1, 2510, 1715),
#   (1, 2510, 1745),
#   (1, 2510, 1778),
#   (1, 2510, 1857),
#   (1, 2510, 1897),
#   (1, 2510, 1927),
#   (1, 2510, 1949),
#   (1, 2510, 2042),
#   (1, 2510, 2109),
#   (1, 2510, 2119),
#   (1, 2510, 2151),
#   (1, 2510, 2386),
#   (1, 2510, 2453),
#   (1, 2510, 2464),
#   (1, 2510, 2656),
#   (1, 2510, 2761),
#   (1, 2510, 2766),
#   (1, 2510, 2800),
#   (1, 2510, 2855),
#   (1, 2510, 2995),
#   (1, 2510, 3096),
#   (1, 2510, 3172),
#   (1, 2510, 3440),
#   (1, 2510, 3450),
#   (1, 2510, 3465),
#   (1, 2510, 3770),
#   (1, 2510, 3801),
#   (1, 2510, 3804),
#   (1, 2510, 3809),
#   (1, 2510, 3885),
#   (1, 2510, 3888),
#   (1, 2510, 4041),
#   (1, 2510, 4089),
#   (1, 2513, 23),
#   (1, 2513, 162),
#   (1, 2513, 243),
#   (1, 2513, 261),
#   (1, 2513, 269),
#   (1, 2513, 436),
#   (1, 2513, 953),
#   (1, 2513, 1123),
#   (1, 2513, 1159),
#   (1, 2513, 1172),
#   (1, 2513, 1230),
#   (1, 2513, 1240),
#   (1, 2513, 1258),
#   (1, 2513, 1304),
#   (1, 2513, 1346),
#   (1, 2513, 1351),
#   (1, 2513, 1407),
#   (1, 2513, 1410),
#   (1, 2513, 1603),
#   (1, 2513, 1668),
#   (1, 2513, 1681),
#   (1, 2513, 1687),
#   (1, 2513, 1690),
#   (1, 2513, 1715),
#   (1, 2513, 1745),
#   (1, 2513, 1778),
#   (1, 2513, 1857),
#   (1, 2513, 1897),
#   (1, 2513, 1927),
#   (1, 2513, 1949),
#   (1, 2513, 2042),
#   (1, 2513, 2109),
#   (1, 2513, 2119),
#   (1, 2513, 2151),
#   (1, 2513, 2386),
#   (1, 2513, 2453),
#   (1, 2513, 2464),
#   (1, 2513, 2656),
#   (1, 2513, 2761),
#   (1, 2513, 2766),
#   (1, 2513, 2800),
#   (1, 2513, 2855),
#   (1, 2513, 2995),
#   (1, 2513, 3096),
#   (1, 2513, 3172),
#   (1, 2513, 3440),
#   (1, 2513, 3450),
#   (1, 2513, 3465),
#   (1, 2513, 3770),
#   (1, 2513, 3801),
#   (1, 2513, 3804),
#   (1, 2513, 3809),
#   (1, 2513, 3885),
#   (1, 2513, 3888),
#   (1, 2513, 4041),
#   (1, 2513, 4089),
#   (1, 2538, 23),
#   (1, 2538, 162),
#   (1, 2538, 243),
#   (1, 2538, 261),
#   (1, 2538, 269),
#   (1, 2538, 436),
#   (1, 2538, 953),
#   (1, 2538, 1123),
#   (1, 2538, 1159),
#   (1, 2538, 1172),
#   (1, 2538, 1230),
#   (1, 2538, 1240),
#   (1, 2538, 1258),
#   (1, 2538, 1304),
#   (1, 2538, 1346),
#   (1, 2538, 1351),
#   (1, 2538, 1407),
#   (1, 2538, 1410),
#   (1, 2538, 1603),
#   (1, 2538, 1668),
#   (1, 2538, 1681),
#   (1, 2538, 1687),
#   (1, 2538, 1690),
#   (1, 2538, 1715),
#   (1, 2538, 1745),
#   (1, 2538, 1778),
#   (1, 2538, 1857),
#   (1, 2538, 1897),
#   (1, 2538, 1927),
#   (1, 2538, 1949),
#   (1, 2538, 2042),
#   (1, 2538, 2109),
#   (1, 2538, 2119),
#   (1, 2538, 2151),
#   (1, 2538, 2386),
#   (1, 2538, 2453),
#   (1, 2538, 2464),
#   (1, 2538, 2656),
#   (1, 2538, 2761),
#   (1, 2538, 2766),
#   (1, 2538, 2800),
#   (1, 2538, 2855),
#   (1, 2538, 2995),
#   (1, 2538, 3096),
#   (1, 2538, 3172),
#   (1, 2538, 3440),
#   (1, 2538, 3450),
#   (1, 2538, 3465),
#   (1, 2538, 3770),
#   (1, 2538, 3801),
#   (1, 2538, 3804),
#   (1, 2538, 3809),
#   (1, 2538, 3885),
#   (1, 2538, 3888),
#   (1, 2538, 4041),
#   (1, 2538, 4089),
#   (1, 2564, 23),
#   (1, 2564, 162),
#   (1, 2564, 243),
#   (1, 2564, 261),
#   (1, 2564, 269),
#   (1, 2564, 436),
#   (1, 2564, 953),
#   (1, 2564, 1123),
#   (1, 2564, 1159),
#   (1, 2564, 1172),
#   (1, 2564, 1230),
#   (1, 2564, 1240),
#   (1, 2564, 1258),
#   (1, 2564, 1304),
#   (1, 2564, 1346),
#   (1, 2564, 1351),
#   (1, 2564, 1407),
#   (1, 2564, 1410),
#   (1, 2564, 1603),
#   (1, 2564, 1668),
#   (1, 2564, 1681),
#   (1, 2564, 1687),
#   (1, 2564, 1690),
#   (1, 2564, 1715),
#   (1, 2564, 1745),
#   (1, 2564, 1778),
#   (1, 2564, 1857),
#   (1, 2564, 1897),
#   (1, 2564, 1927),
#   (1, 2564, 1949),
#   (1, 2564, 2042),
#   (1, 2564, 2109),
#   (1, 2564, 2119),
#   (1, 2564, 2151),
#   (1, 2564, 2386),
#   (1, 2564, 2453),
#   (1, 2564, 2464),
#   (1, 2564, 2656),
#   (1, 2564, 2761),
#   (1, 2564, 2766),
#   (1, 2564, 2800),
#   (1, 2564, 2855),
#   (1, 2564, 2995),
#   (1, 2564, 3096),
#   (1, 2564, 3172),
#   (1, 2564, 3440),
#   (1, 2564, 3450),
#   (1, 2564, 3465),
#   (1, 2564, 3770),
#   (1, 2564, 3801),
#   (1, 2564, 3804),
#   (1, 2564, 3809),
#   (1, 2564, 3885),
#   (1, 2564, 3888),
#   (1, 2564, 4041),
#   (1, 2564, 4089),
#   (1, 2574, 23),
#   (1, 2574, 162),
#   (1, 2574, 243),
#   (1, 2574, 261),
#   (1, 2574, 269),
#   (1, 2574, 436),
#   (1, 2574, 953),
#   (1, 2574, 1123),
#   (1, 2574, 1159),
#   (1, 2574, 1172),
#   (1, 2574, 1230),
#   (1, 2574, 1240),
#   (1, 2574, 1258),
#   (1, 2574, 1304),
#   (1, 2574, 1346),
#   (1, 2574, 1351),
#   (1, 2574, 1407),
#   (1, 2574, 1410),
#   (1, 2574, 1603),
#   (1, 2574, 1668),
#   (1, 2574, 1681),
#   (1, 2574, 1687),
#   (1, 2574, 1690),
#   (1, 2574, 1715),
#   (1, 2574, 1745),
#   (1, 2574, 1778),
#   (1, 2574, 1857),
#   (1, 2574, 1897),
#   (1, 2574, 1927),
#   (1, 2574, 1949),
#   (1, 2574, 2042),
#   (1, 2574, 2109),
#   (1, 2574, 2119),
#   (1, 2574, 2151),
#   (1, 2574, 2386),
#   (1, 2574, 2453),
#   (1, 2574, 2464),
#   (1, 2574, 2656),
#   (1, 2574, 2761),
#   (1, 2574, 2766),
#   (1, 2574, 2800),
#   (1, 2574, 2855),
#   (1, 2574, 2995),
#   (1, 2574, 3096),
#   (1, 2574, 3172),
#   (1, 2574, 3440),
#   (1, 2574, 3450),
#   (1, 2574, 3465),
#   (1, 2574, 3770),
#   (1, 2574, 3801),
#   (1, 2574, 3804),
#   (1, 2574, 3809),
#   (1, 2574, 3885),
#   (1, 2574, 3888),
#   (1, 2574, 4041),
#   (1, 2574, 4089),
#   (1, 2587, 23),
#   (1, 2587, 162),
#   (1, 2587, 243),
#   (1, 2587, 261),
#   (1, 2587, 269),
#   (1, 2587, 436),
#   (1, 2587, 953),
#   (1, 2587, 1123),
#   (1, 2587, 1159),
#   (1, 2587, 1172),
#   (1, 2587, 1230),
#   (1, 2587, 1240),
#   (1, 2587, 1258),
#   (1, 2587, 1304),
#   (1, 2587, 1346),
#   (1, 2587, 1351),
#   (1, 2587, 1407),
#   (1, 2587, 1410),
#   (1, 2587, 1603),
#   (1, 2587, 1668),
#   (1, 2587, 1681),
#   (1, 2587, 1687),
#   (1, 2587, 1690),
#   (1, 2587, 1715),
#   (1, 2587, 1745),
#   (1, 2587, 1778),
#   (1, 2587, 1857),
#   (1, 2587, 1897),
#   (1, 2587, 1927),
#   (1, 2587, 1949),
#   (1, 2587, 2042),
#   (1, 2587, 2109),
#   (1, 2587, 2119),
#   (1, 2587, 2151),
#   (1, 2587, 2386),
#   (1, 2587, 2453),
#   (1, 2587, 2464),
#   (1, 2587, 2656),
#   (1, 2587, 2761),
#   (1, 2587, 2766),
#   (1, 2587, 2800),
#   (1, 2587, 2855),
#   (1, 2587, 2995),
#   (1, 2587, 3096),
#   (1, 2587, 3172),
#   (1, 2587, 3440),
#   (1, 2587, 3450),
#   (1, 2587, 3465),
#   ...],
#  [145, 19])

# %% [markdown]
# ## 基于内容的排名
# 我们需要找到一种针对给定查询条件为网页进行评价的方法，并且能在返回结果中将评价最高者排在最前面。
#
# 我们将对几种只依据查询条件和网页内容进行评价计算的方法进行考察。包含以下三种：
# - 单词频度TD（TDIDF）。位于查询条件中的单词在文档中出现的次数能有助于我们判断文档的相关程度
# - 文档位置。文档的主题可能会出现在靠近文档的开始处
# - 单词距离。如果查询的条件中有个单词，则它们在文档中的位置应该靠的很近
#
# 早期搜索引擎只用了上面几种方法，就已经取得了比较好的结果
#
# 在searcher类中添加一个新的方法，接收查询请求，将获取到的行集置于字典中，并以格式化列表的形式显示输出。

# %%
class searcher:
    def __init__(self,dbname):
        self.con=sqlite3.connect(dbname)
    
    def __del__(self):
        self.con.close()
        
    def getmatchrows(self,q):
        # 构造查询的字符串
        fieldlist='w0.urlid'
        tablelist=''
        clauselist=''
        wordids=[]
        
        # 根据空格拆分单词
        words=q.split(' ')  
        tablenumber=0

        for word in words:
            # 获取单词的ID
            wordrow=self.con.execute("select rowid from wordlist where word='%s'" % word).fetchone()
            if wordrow!=None:
                wordid=wordrow[0]
                wordids.append(wordid)
                if tablenumber>0:
                    tablelist+=','
                    clauselist+=' and '
                    clauselist+='w%d.urlid=w%d.urlid and ' % (tablenumber-1,tablenumber)
                fieldlist+=',w%d.location' % tablenumber
                tablelist+='wordlocation w%d' % tablenumber      
                clauselist+='w%d.wordid=%d' % (tablenumber,wordid)
                tablenumber+=1

        # 根据各个组分，建立查询
        fullquery='select %s from %s where %s' % (fieldlist,tablelist,clauselist)
        print(fullquery)
        cur=self.con.execute(fullquery)
        rows=[row for row in cur]

        return rows,wordids
    
    # 接收查询请求，将获取到的行集置于字典中，并以格式化的形式输出
    def getscoredlist(self,rows,wordids):
        totalscores=dict([(row[0],0) for row in rows])
        
        # 评价函数
#         weights=[(1.0,self.locationscore(rows)), 
#              (1.0,self.frequencyscore(rows)),
#              (1.0,self.pagerankscore(rows)),
#              (1.0,self.linktextscore(rows,wordids)),
#              (5.0,self.nnscore(rows,wordids))]
        weights=[]
        
        for (weight,scores) in weights:
            for url in totalscores:
                totalscores[url]+=weight*scores[url]
                
        return totalscores
    
    def geturlname(self,id):
        return self.con.execute("select url from urllist where rowid=%d" % id).fetchone()[0]
    
    def query(self,q):
        rows,wordids=self.getmatchrows(q) # 查询
        scores=self.getscoredlist(rows,wordids)
        rankedscores=[(score,url) for (url,score) in scores.items()] # 排序
        rankedscores.sort()
        rankedscores.reverse()
        for (score,urlid) in rankedscores[0:10]: # 得到前十的结果
            print('%f\t%s' % (score,self.geturlname(urlid)))
        
        return wordids,[r[1] for r in rankedscores[0:10]]

# %% [markdown]
# query方法还没有评价函数

# %%
e=searcher('searchindex.db')
e.query('functional programming')
# Out:
# select w0.urlid,w0.location,w1.location from wordlocation w0,wordlocation w1 where w0.wordid=145 and w0.urlid=w1.urlid and w1.wordid=19
# 0.000000	http://kiwitobes.com/wiki/XSLT.html
# 0.000000	http://kiwitobes.com/wiki/XQuery.html
# 0.000000	http://kiwitobes.com/wiki/Unified_Modeling_Language.html
# 0.000000	http://kiwitobes.com/wiki/SNOBOL.html
# 0.000000	http://kiwitobes.com/wiki/Procedural_programming.html
# 0.000000	http://kiwitobes.com/wiki/Miranda_programming_language.html
# 0.000000	http://kiwitobes.com/wiki/ISWIM.html
# 0.000000	http://kiwitobes.com/wiki/Smalltalk_programming_language.html
# 0.000000	http://kiwitobes.com/wiki/Self_programming_language.html
# 0.000000	http://kiwitobes.com/wiki/MOO_programming_language.html
# ([145, 19], [437, 436, 419, 389, 373, 372, 370, 365, 364, 361])

# %% [markdown]
# ### 归一化函数
# 归一化函数normalizescores接收一个包含ID与评价值的字典，并返回一个带有相同ID，而评价值则介于0,1之间的新字典。
#
# 函数根据每个评价值与最佳结果的接近程度（最佳结果的对应值为1），对其做了相应的缩放处理。

# %%
class searcher:
    def __init__(self,dbname):
        self.con=sqlite3.connect(dbname)
    
    def __del__(self):
        self.con.close()
        
    def getmatchrows(self,q):
        # 构造查询的字符串
        fieldlist='w0.urlid'
        tablelist=''
        clauselist=''
        wordids=[]
        
        # 根据空格拆分单词
        words=q.split(' ')  
        tablenumber=0

        for word in words:
            # 获取单词的ID
            wordrow=self.con.execute("select rowid from wordlist where word='%s'" % word).fetchone()
            if wordrow!=None:
                wordid=wordrow[0]
                wordids.append(wordid)
                if tablenumber>0:
                    tablelist+=','
                    clauselist+=' and '
                    clauselist+='w%d.urlid=w%d.urlid and ' % (tablenumber-1,tablenumber)
                fieldlist+=',w%d.location' % tablenumber
                tablelist+='wordlocation w%d' % tablenumber      
                clauselist+='w%d.wordid=%d' % (tablenumber,wordid)
                tablenumber+=1

        # 根据各个组分，建立查询
        fullquery='select %s from %s where %s' % (fieldlist,tablelist,clauselist)
        print(fullquery)
        cur=self.con.execute(fullquery)
        rows=[row for row in cur]

        return rows,wordids
    
    # 接收查询请求，将获取到的行集置于字典中，并以格式化的形式输出
    def getscoredlist(self,rows,wordids):
        totalscores=dict([(row[0],0) for row in rows])
        
        # 评价函数
#         weights=[(1.0,self.locationscore(rows)), 
#              (1.0,self.frequencyscore(rows)),
#              (1.0,self.pagerankscore(rows)),
#              (1.0,self.linktextscore(rows,wordids)),
#              (5.0,self.nnscore(rows,wordids))]
        weights=[]
        
        for (weight,scores) in weights:
            for url in totalscores:
                totalscores[url]+=weight*scores[url]
                
        return totalscores
    
    def geturlname(self,id):
        return self.con.execute("select url from urllist where rowid=%d" % id).fetchone()[0]
    
    def query(self,q):
        rows,wordids=self.getmatchrows(q) # 查询
        scores=self.getscoredlist(rows,wordids)
        rankedscores=[(score,url) for (url,score) in scores.items()] # 排序
        rankedscores.sort()
        rankedscores.reverse()
        for (score,urlid) in rankedscores[0:10]: # 得到前十的结果
            print('%f\t%s' % (score,self.geturlname(urlid)))
        
        return wordids,[r[1] for r in rankedscores[0:10]]
    
    # 将评价值列表传入该函数，并指明数值越小越好，还是越大越好
    def normalizescores(self,scores,smallIsBetter=0):
        vsmall=0.00001
        if smallIsBetter:
            minscore=min(scores.values()) # 评价的最小分值/分值或者0.00001，分值越小，评价越高
            return dict([(u,float(minscore)/max(vsmall,l)) for (u,l) in scores.items()])
        else:
            maxscore=max(scores.values())
            if maxscore==0:
                maxscore=vsmall
            return dict([(u,float(c)/maxscore) for (u,c) in scores.items()])

# %% [markdown]
# ### 单词频度
# 频度越高，说明网页更加靠谱
#
# 我们将frequencyscore添加入searcher类中

# %%
class searcher:
    def __init__(self,dbname):
        self.con=sqlite3.connect(dbname)
    
    def __del__(self):
        self.con.close()
        
    def getmatchrows(self,q):
        # 构造查询的字符串
        fieldlist='w0.urlid'
        tablelist=''
        clauselist=''
        wordids=[]
        
        # 根据空格拆分单词
        words=q.split(' ')  
        tablenumber=0

        for word in words:
            # 获取单词的ID
            wordrow=self.con.execute("select rowid from wordlist where word='%s'" % word).fetchone()
            if wordrow!=None:
                wordid=wordrow[0]
                wordids.append(wordid)
                if tablenumber>0:
                    tablelist+=','
                    clauselist+=' and '
                    clauselist+='w%d.urlid=w%d.urlid and ' % (tablenumber-1,tablenumber)
                fieldlist+=',w%d.location' % tablenumber
                tablelist+='wordlocation w%d' % tablenumber      
                clauselist+='w%d.wordid=%d' % (tablenumber,wordid)
                tablenumber+=1

        # 根据各个组分，建立查询
        fullquery='select %s from %s where %s' % (fieldlist,tablelist,clauselist)
        print(fullquery)
        cur=self.con.execute(fullquery)
        rows=[row for row in cur]

        return rows,wordids
    
    # 接收查询请求，将获取到的行集置于字典中，并以格式化的形式输出
    def getscoredlist(self,rows,wordids):
        totalscores=dict([(row[0],0) for row in rows])
        
        # 评价函数
#         weights=[(1.0,self.locationscore(rows)), 
#              (1.0,self.frequencyscore(rows)),
#              (1.0,self.pagerankscore(rows)),
#              (1.0,self.linktextscore(rows,wordids)),
#              (5.0,self.nnscore(rows,wordids))]
        weights=[(1.0,self.frequencyscore(rows))]
        
        for (weight,scores) in weights:
            for url in totalscores:
                totalscores[url]+=weight*scores[url]
                
        return totalscores
    
    def geturlname(self,id):
        return self.con.execute("select url from urllist where rowid=%d" % id).fetchone()[0]
    
    def query(self,q):
        rows,wordids=self.getmatchrows(q) # 查询
        scores=self.getscoredlist(rows,wordids)
        rankedscores=[(score,url) for (url,score) in scores.items()] # 排序
        rankedscores.sort()
        rankedscores.reverse()
        for (score,urlid) in rankedscores[0:10]: # 得到前十的结果
            print('%f\t%s' % (score,self.geturlname(urlid)))
        
        return wordids,[r[1] for r in rankedscores[0:10]]
    
    # 将评价值列表传入该函数，并指明数值越小越好，还是越大越好
    def normalizescores(self,scores,smallIsBetter=0):
        vsmall=0.00001
        if smallIsBetter:
            minscore=min(scores.values()) # 评价的最小分值/分值或者0.00001，分值越小，评价越高
            return dict([(u,float(minscore)/max(vsmall,l)) for (u,l) in scores.items()])
        else:
            maxscore=max(scores.values())
            if maxscore==0:
                maxscore=vsmall
            return dict([(u,float(c)/maxscore) for (u,c) in scores.items()])
    
    # 单词频度函数
    def frequencyscore(self,rows):
        counts=dict([row[0],0] for row in rows)
        for row in rows:
            counts[row[0]]+=1
        return self.normalizescores(counts)

# %%
e=searcher('searchindex.db')
e.query('functional programming')
# Out:
# select w0.urlid,w0.location,w1.location from wordlocation w0,wordlocation w1 where w0.wordid=145 and w0.urlid=w1.urlid and w1.wordid=19
# 1.000000	http://kiwitobes.com/wiki/Functional_programming.html
# 0.262476	http://kiwitobes.com/wiki/Categorical_list_of_programming_languages.html
# 0.062310	http://kiwitobes.com/wiki/Programming_language.html
# 0.043976	http://kiwitobes.com/wiki/Lisp_programming_language.html
# 0.036394	http://kiwitobes.com/wiki/Programming_paradigm.html
# 0.030880	http://kiwitobes.com/wiki/Multi-paradigm_programming_language.html
# 0.027295	http://kiwitobes.com/wiki/Perl.html
# 0.022057	http://kiwitobes.com/wiki/Declarative_programming.html
# 0.020265	http://kiwitobes.com/wiki/Generic_programming.html
# 0.019024	http://kiwitobes.com/wiki/Object-oriented_programming.html
# ([145, 19], [220, 1, 2, 227, 289, 288, 171, 196, 293, 296])

# %% [markdown]
# ### 文档位置
# 一个网页与待搜索的单词相关，则该单词就更有可能在靠近网页开始的位置出现

# %%
class searcher:
    def __init__(self,dbname):
        self.con=sqlite3.connect(dbname)
    
    def __del__(self):
        self.con.close()
        
    def getmatchrows(self,q):
        # 构造查询的字符串
        fieldlist='w0.urlid'
        tablelist=''
        clauselist=''
        wordids=[]
        
        # 根据空格拆分单词
        words=q.split(' ')  
        tablenumber=0

        for word in words:
            # 获取单词的ID
            wordrow=self.con.execute("select rowid from wordlist where word='%s'" % word).fetchone()
            if wordrow!=None:
                wordid=wordrow[0]
                wordids.append(wordid)
                if tablenumber>0:
                    tablelist+=','
                    clauselist+=' and '
                    clauselist+='w%d.urlid=w%d.urlid and ' % (tablenumber-1,tablenumber)
                fieldlist+=',w%d.location' % tablenumber
                tablelist+='wordlocation w%d' % tablenumber      
                clauselist+='w%d.wordid=%d' % (tablenumber,wordid)
                tablenumber+=1

        # 根据各个组分，建立查询
        fullquery='select %s from %s where %s' % (fieldlist,tablelist,clauselist)
        print(fullquery)
        cur=self.con.execute(fullquery)
        rows=[row for row in cur]

        return rows,wordids
    
    # 接收查询请求，将获取到的行集置于字典中，并以格式化的形式输出
    def getscoredlist(self,rows,wordids):
        totalscores=dict([(row[0],0) for row in rows])
        
        # 评价函数
#         weights=[(1.0,self.locationscore(rows)), 
#              (1.0,self.frequencyscore(rows)),
#              (1.0,self.pagerankscore(rows)),
#              (1.0,self.linktextscore(rows,wordids)),
#              (5.0,self.nnscore(rows,wordids))]
        weights=[(1.0,self.locationscore(rows))]
        
        for (weight,scores) in weights:
            for url in totalscores:
                totalscores[url]+=weight*scores[url]
                
        return totalscores
    
    def geturlname(self,id):
        return self.con.execute("select url from urllist where rowid=%d" % id).fetchone()[0]
    
    def query(self,q):
        rows,wordids=self.getmatchrows(q) # 查询
        scores=self.getscoredlist(rows,wordids)
        rankedscores=[(score,url) for (url,score) in scores.items()] # 排序
        rankedscores.sort()
        rankedscores.reverse()
        for (score,urlid) in rankedscores[0:10]: # 得到前十的结果
            print('%f\t%s' % (score,self.geturlname(urlid)))
        
        return wordids,[r[1] for r in rankedscores[0:10]]
    
    # 将评价值列表传入该函数，并指明数值越小越好，还是越大越好
    def normalizescores(self,scores,smallIsBetter=0):
        vsmall=0.00001
        if smallIsBetter:
            minscore=min(scores.values()) # 评价的最小分值/分值或者0.00001，分值越小，评价越高
            return dict([(u,float(minscore)/max(vsmall,l)) for (u,l) in scores.items()])
        else:
            maxscore=max(scores.values())
            if maxscore==0:
                maxscore=vsmall
            return dict([(u,float(c)/maxscore) for (u,c) in scores.items()])
    
    # 单词频度函数
    def frequencyscore(self,rows):
        counts=dict([row[0],0] for row in rows)
        for row in rows:
            counts[row[0]]+=1
        return self.normalizescores(counts)
    
    # 文档位置
    def locationscore(self,rows):
        locations=dict([(row[0],1000000) for row in rows])
        for row in rows:
            loc=sum(row[1:])
            if loc<locations[row[0]]:
                locations[row[0]]=loc
        
        return self.normalizescores(locations,smallIsBetter=1)

# %%
e=searcher('searchindex.db')
e.query('functional programming')
# Out:
# select w0.urlid,w0.location,w1.location from wordlocation w0,wordlocation w1 where w0.wordid=145 and w0.urlid=w1.urlid and w1.wordid=19
# 1.000000	http://kiwitobes.com/wiki/Functional_programming.html
# 0.150183	http://kiwitobes.com/wiki/Haskell_programming_language.html
# 0.149635	http://kiwitobes.com/wiki/Opal_programming_language.html
# 0.149091	http://kiwitobes.com/wiki/Miranda_programming_language.html
# 0.149091	http://kiwitobes.com/wiki/Joy_programming_language.html
# 0.149091	http://kiwitobes.com/wiki/Dylan_programming_language.html
# 0.149091	http://kiwitobes.com/wiki/Charity_programming_language.html
# 0.149091	http://kiwitobes.com/wiki/Curry_programming_language.html
# 0.149091	http://kiwitobes.com/wiki/Scheme_programming_language.html
# 0.148551	http://kiwitobes.com/wiki/Logo_programming_language.html
# ([145, 19], [220, 225, 232, 372, 226, 223, 221, 141, 125, 253])

# %% [markdown]
# ### 单词距离
# 寻找单词彼此间距更近的网页是很有意义的
#
# 加入一个新方法distancescore

# %%
class searcher:
    def __init__(self,dbname):
        self.con=sqlite3.connect(dbname)
    
    def __del__(self):
        self.con.close()
        
    def getmatchrows(self,q):
        # 构造查询的字符串
        fieldlist='w0.urlid'
        tablelist=''
        clauselist=''
        wordids=[]
        
        # 根据空格拆分单词
        words=q.split(' ')  
        tablenumber=0

        for word in words:
            # 获取单词的ID
            wordrow=self.con.execute("select rowid from wordlist where word='%s'" % word).fetchone()
            if wordrow!=None:
                wordid=wordrow[0]
                wordids.append(wordid)
                if tablenumber>0:
                    tablelist+=','
                    clauselist+=' and '
                    clauselist+='w%d.urlid=w%d.urlid and ' % (tablenumber-1,tablenumber)
                fieldlist+=',w%d.location' % tablenumber
                tablelist+='wordlocation w%d' % tablenumber      
                clauselist+='w%d.wordid=%d' % (tablenumber,wordid)
                tablenumber+=1

        # 根据各个组分，建立查询
        fullquery='select %s from %s where %s' % (fieldlist,tablelist,clauselist)
        print(fullquery)
        cur=self.con.execute(fullquery)
        rows=[row for row in cur]

        return rows,wordids
    
    # 接收查询请求，将获取到的行集置于字典中，并以格式化的形式输出
    def getscoredlist(self,rows,wordids):
        totalscores=dict([(row[0],0) for row in rows])
        
        # 评价函数
#         weights=[(1.0,self.locationscore(rows)), 
#              (1.0,self.frequencyscore(rows)),
#              (1.0,self.pagerankscore(rows)),
#              (1.0,self.linktextscore(rows,wordids)),
#              (5.0,self.nnscore(rows,wordids))]
        weights=[(1.0,self.distancescore(rows))]
        
        for (weight,scores) in weights:
            for url in totalscores:
                totalscores[url]+=weight*scores[url]
                
        return totalscores
    
    def geturlname(self,id):
        return self.con.execute("select url from urllist where rowid=%d" % id).fetchone()[0]
    
    def query(self,q):
        rows,wordids=self.getmatchrows(q) # 查询
        scores=self.getscoredlist(rows,wordids)
        rankedscores=[(score,url) for (url,score) in scores.items()] # 排序
        rankedscores.sort()
        rankedscores.reverse()
        for (score,urlid) in rankedscores[0:10]: # 得到前十的结果
            print('%f\t%s' % (score,self.geturlname(urlid)))
        
        return wordids,[r[1] for r in rankedscores[0:10]]
    
    # 将评价值列表传入该函数，并指明数值越小越好，还是越大越好
    def normalizescores(self,scores,smallIsBetter=0):
        vsmall=0.00001
        if smallIsBetter:
            minscore=min(scores.values()) # 评价的最小分值/分值或者0.00001，分值越小，评价越高
            return dict([(u,float(minscore)/max(vsmall,l)) for (u,l) in scores.items()])
        else:
            maxscore=max(scores.values())
            if maxscore==0:
                maxscore=vsmall
            return dict([(u,float(c)/maxscore) for (u,c) in scores.items()])
    
    # 单词频度函数
    def frequencyscore(self,rows):
        counts=dict([row[0],0] for row in rows)
        for row in rows:
            counts[row[0]]+=1
        return self.normalizescores(counts)
    
    # 文档位置
    def locationscore(self,rows):
        locations=dict([(row[0],1000000) for row in rows])
        for row in rows:
            loc=sum(row[1:])
            if loc<locations[row[0]]:
                locations[row[0]]=loc
        
        return self.normalizescores(locations,smallIsBetter=1)
    
    # 单词距离
    def distancescore(self,rows):
        # 如果仅有一个单词，得分都一样
        if len(rows[0])<=2: return dict([(row[0],1.0) for row in rows])

        # 初始化字典，并填入一个很大的数
        mindistance=dict([(row[0],1000000) for row in rows])

        for row in rows:
            dist=sum([abs(row[i]-row[i-1]) for i in range(2,len(row))])
            if dist<mindistance[row[0]]: mindistance[row[0]]=dist
        return self.normalizescores(mindistance,smallIsBetter=1) # 找出总距离的最小值

# %%
e=searcher('searchindex.db')
e.query('functional programming')
# Out:
# select w0.urlid,w0.location,w1.location from wordlocation w0,wordlocation w1 where w0.wordid=145 and w0.urlid=w1.urlid and w1.wordid=19
# 1.000000	http://kiwitobes.com/wiki/XSLT.html
# 1.000000	http://kiwitobes.com/wiki/XQuery.html
# 1.000000	http://kiwitobes.com/wiki/Procedural_programming.html
# 1.000000	http://kiwitobes.com/wiki/Miranda_programming_language.html
# 1.000000	http://kiwitobes.com/wiki/ISWIM.html
# 1.000000	http://kiwitobes.com/wiki/Smalltalk_programming_language.html
# 1.000000	http://kiwitobes.com/wiki/MOO_programming_language.html
# 1.000000	http://kiwitobes.com/wiki/SuperCollider.html
# 1.000000	http://kiwitobes.com/wiki/Smalltalk.html
# 1.000000	http://kiwitobes.com/wiki/Sather_programming_language.html
# ([145, 19], [437, 436, 373, 372, 370, 365, 361, 352, 345, 342])
